# %%
import re
#from fathomnet.api import worms, taxa
import csv
from pynoddgcs.connect import GCS
import tempfile
import json
import pyworms
import re

# %%
REFRESH = True

# %%
SOURCE_BUCKET = "nmfs_odp_hq"
SOURCE_FILE = "nodd_tools/datasets/gfisher/annotations.json"

# %%
client = GCS()

# %%
with tempfile.NamedTemporaryFile() as f:
    client.download(SOURCE_BUCKET, SOURCE_FILE, f.name)
    raw_coco = json.load(f)

# %%
observed_categories = [cat["name"] for cat in raw_coco["categories"]]
observed_categories
# Out:
# ['MYCTEROPERCAMICROLEPIS-170022104',
#  'SERRANUSPHOEBE-170024208',
#  'SERIOLAFASCIATA-170113103',
#  'RHOMBOPLITESAURORUBENS-170152001',
#  'LUTJANUSSYNAGRIS-170151113',
#  'CALLIONYMIDAE-170420000',
#  'EPINEPHELUSMORIO-170021211',
#  'HALICHOERES-170281200',
#  'PTEROIS-168011900',
#  'BODIANUSPULCHELLUS-170280201',
#  'HAEMULONAUROLINEATUM-170191003',
#  'LUTJANUSGRISEUS-170151109',
#  'POMACENTRIDAE-170270000',
#  'UNKNOWNFISH',
#  'SERIOLA-170113100',
#  'PRISTIGENYSALTA-170050401',
#  'CARANXBARTHOLOMAEI-170110801',
#  'BALISTESCAPRISCUS-189030502',
#  'LUTJANUSCAMPECHANUS-170151107',
#  'CHAETODONOCELLATUS-170260307',
#  'HOLACANTHUSBERMUDENSIS-170290102',
#  'MYCTEROPERCAPHENAX-170022105',
#  'CEPHALOPHOLISCRUENTATA-170020401',
#  'LUTJANUS-170151100',
#  'SCOMBEROMORUSMACULATUS-170440803',
#  'CARANXCRYSOS-170110803',
#  'CHAETODONSEDENTARIUS-170260309',
#  'PAGRUSPAGRUS-170212302',
#  'DIPLECTRUMFORMOSUM-170020903',
#  'CHAETODON-170260300',
#  'CALAMUS-170210600',
#  'SERIOLARIVOLIANA-170113105',
#  'LUTJANUSVIVANUS-170151114',
#  'BALISTESVETULA-189030504',
#  'MYCTEROPERCAINTERSTITIALIS-170022103',
#  'SERRANUSANNULARIS-170024201',
#  'MYCTEROPERCABONACI-170022101',
#  'CANTHIGASTERROSTRATA-189080101',
#  'HALICHOERESBIVITTATUS-170281202',
#  'PARANTHIASFURCIFER-170022701',
#  'PRONOTOGRAMMUSMARTINICENSIS-170025101',
#  'OPISTOGNATHUS-170310200',
#  'SERRANUS-170024200',
#  'SERIOLAZONATA-170113106',
#  'SPHYRNALEWINI-108040102',
#  'MYCTEROPERCA-170022100',
#  'ANISOTREMUSVIRGINICUS-170190105',
#  'HYPORTHODUSNIGRITUS-170021202',
#  'CARANGIDAE-170110000',
#  'CHROMIS-170270300',
#  'CHAETODONCAPISTRATUS-170260302',
#  'PRIACANTHUSARENATUS-170050101',
#  'XANTHICHTHYSRINGENS-189030101',
#  'HOLOCENTRUS-161110200',
#  'CALAMUSLEUCOSTEUS-170210604',
#  'ANOMURA-999100401',
#  'SERIOLADUMERILI-170113101',
#  'LACHNOLAIMUSMAXIMUS-170281801',
#  'UPENEUSPARVUS-170220605',
#  'IOGLOSSUS-170550800',
#  'MALACANTHUSPLUMIERI-170070301',
#  'HALICHOERESBATHYPHILUS-170281201',
#  'CARCHARHINUS-108020200',
#  'DECAPTERUS-170111200',
#  'CARCHARHINUSPLUMBEUS-108020208',
#  'SYNODONTIDAE-129040000',
#  'SYACIUM-183011000',
#  'CANTHIDERMISSUFFLAMEN-189030402',
#  'ALECTISCILIARIS-170110101',
#  'GOBIIDAE-170550000',
#  'EPINEPHELUS-170021200',
#  'UROPHYCISREGIA-148010105',
#  'OPISTOGNATHUSAURIFRONS-170310203',
#  'CENTROPRISTISOCYURUS-170024804',
#  'MURAENARETIFERA-143060402',
#  'DERMATOLEPISINERMIS-170020301',
#  'POMACANTHUSARCUATUS-170290201',
#  'PAREQUESUMBROSUS-170201105',
#  'OPHICHTHUSPUNCTICEPS-143150402',
#  'POMACANTHUSPARU-170290203',
#  'HYPORTHODUSFLAVOLIMBATUS-170021206',
#  'CHROMISENCHRYSURUS-170270302',
#  'LUTJANUSAPODUS-170151102',
#  'CALAMUSNODOSUS-170210608',
#  'CARCHARHINUSFALCIFORMIS-108020202',
#  'ANTHIINAE-999020300',
#  'GYMNOTHORAXSAXICOLA-143060205',
#  'CAULOLATILUSCYANOPS-170070101',
#  'GYMNOTHORAXMORINGA-143060202',
#  'CALAMUSPRORIDENS-170210605',
#  'HOLOCENTRUSADSCENSIONIS-161110201',
#  'SPHYRAENABARRACUDA-165030101',
#  'HYPOPLECTRUS-170021500',
#  'CALAMUSBAJONADO-170210602',
#  'CARANXRUBER-170110807',
#  'GONIOPLECTRUSHISPANUS-170021403',
#  'BODIANUSRUFUS-170280202',
#  'EPINEPHELUSADSCENSIONIS-170021203',
#  'PROGNATHODESAYA-170260301',
#  'DECODONPUELLARIS-170283001',
#  'CAULOLATILUSMICROPS-170070103',
#  'STENOCIONOPSSPINIMANA-229211803',
#  'CAULOLATILUSCHRYSOPS-170070104',
#  'OSTICHTHYSTRACHYPOMUS-161110601',
#  'LUTJANUSANALIS-170151101',
#  'CHROMISINSOLATUS-170270304',
#  'SERRANUSTORTUGARUM-170024211',
#  'MONACANTHUSTUCKERI-189040203',
#  'CANTHIGASTERJAMESTYLERI-189080102',
#  'LIOPROPOMAEUKRINES-170025602',
#  'MULLIDAE-170220000',
#  'HAEMULONALBUM-170191002',
#  'PRISTIPOMOIDES-170151800',
#  'SCHOOL',
#  'SERRANUSATROBRANCHUS-170024202',
#  'ALBULAVULPES-121030101',
#  'ARCHOSARGUSPROBATOCEPHALUS-170213601',
#  'SCOMBEROMORUS-170440800',
#  'CENTROPRISTISPHILADELPHICA-170024805',
#  'STENOTOMUSCAPRINUS-170213403',
#  'SELENEVOMER-170113003',
#  'CHAETODIPTERUSFABER-170250101',
#  'HOLACANTHUS-170290100',
#  'SERRANUSSUBLIGARIUS-170024209']

# %%
with open('Species List.csv', 'r') as f:
    reader = csv.reader(f)
    header = next(reader)
    name_map = {concatenated_name: better_name for _, concatenated_name, better_name, _, _ in reader}
name_map
# Out:
# {'ABUDEFDUFSAXATILIS-170270101': 'ABUDEFDUF_SAXATILIS',
#  'ABUDEFDUFTAURUS-170270102': 'ABUDEFDUF_TAURUS',
#  'ACANTHURUSBAHIANUS-170160101': 'ACANTHURUS_BAHIANUS',
#  'ACANTHURUSCHIRURGUS-170160103': 'ACANTHURUS_CHIRURGUS',
#  'ACANTHURUSCOERULEUS-170160102': 'ACANTHURUS_COERULEUS',
#  'ALBULAVULPES-121030101': 'ALBULA_VULPES',
#  'ALECTISCILIARIS-170110101': 'ALECTIS_CILIARIS',
#  'AMBLYCIRRHITUSPINOS-170590101': 'AMBLYCIRRHITUS_PINOS',
#  'ANISOTREMUSSURINAMENSIS-170190106': 'ANISOTREMUS_SURINAMENSIS',
#  'ANISOTREMUSVIRGINICUS-170190105': 'ANISOTREMUS_VIRGINICUS',
#  'ANTENNARIUSOCELLATUS-195020101': 'ANTENNARIUS_OCELLATUS',
#  'ANTHIASASPERILINGUIS-170026001': 'ANTHIAS_ASPERILINGUIS',
#  'ANTHIASNICHOLSI-170026002': 'ANTHIAS_NICHOLSI',
#  'ANTHIASTENUIS-170026003': 'ANTHIAS_TENUIS',
#  'ANTHIASWOODSI-170026004': 'ANTHIAS_WOODSI',
#  'ANTIGONIA-162030100': 'ANTIGONIA',
#  'ANTIGONIACAPROS-162030101': 'ANTIGONIA_CAPROS',
#  'APOGONAFFINI-170060204': 'APOGON_AFFINI',
#  'APOGONALUTUS-170060212': 'APOGON_ALUTUS',
#  'APOGONAMERICANUS-170060214': 'APOGON_AMERICANUS',
#  'APOGONAUROLINEATUS-170060201': 'APOGON_AUROLINEATUS',
#  'APOGONBINOTATUS-170060202': 'APOGON_BINOTATUS',
#  'APOGONCONKLINI-170060213': 'APOGON_CONKLINI',
#  'APOGONLACHNERI-170060209': 'APOGON_LACHNERI',
#  'APOGONMACULATUS-170060203': 'APOGON_MACULATUS',
#  'APOGONPHENAX-170060210': 'APOGON_PHENAX',
#  'APOGONPIGMENTARIUS-170060205': 'APOGON_PIGMENTARIUS',
#  'APOGONPILLIONATUS-170060215': 'APOGON_PILLIONATUS',
#  'APOGONPLANIFRONS-170060206': 'APOGON_PLANIFRONS',
#  'APOGONPSEUDOMACULATUS-170060207': 'APOGON_PSEUDOMACULATUS',
#  'APOGONQUADRISQUAMATUS-170060208': 'APOGON_QUADRISQUAMATUS',
#  'APOGONTOWNSENDI-170060211': 'APOGON_TOWNSENDI',
#  'APSILUSDENTATUS-170150301': 'APSILUS_DENTATUS',
#  'ARCHOSARGUSPROBATOCEPHALUS-170213601': 'ARCHOSARGUS_PROBATOCEPHALUS',
#  'AULOSTOMUSMACULATUS-151010101': 'AULOSTOMUS_MACULATUS',
#  'BALISTESCAPRISCUS-189030502': 'BALISTES_CAPRISCUS',
#  'BALISTESVETULA-189030504': 'BALISTES_VETULA',
#  'BODIANUSPULCHELLUS-170280201': 'BODIANUS_PULCHELLUS',
#  'BODIANUSRUFUS-170280202': 'BODIANUS_RUFUS',
#  'CALAMUSBAJONADO-170210602': 'CALAMUS_BAJONADO',
#  'CALAMUSCALAMUS-170210603': 'CALAMUS_CALAMUS',
#  'CALAMUSLEUCOSTEUS-170210604': 'CALAMUS_LEUCOSTEUS',
#  'CALAMUSNODOSUS-170210608': 'CALAMUS_NODOSUS',
#  'CALAMUSPENNATULA-170210607': 'CALAMUS_PENNATULA',
#  'CALAMUSPRORIDENS-170210605': 'CALAMUS_PRORIDENS',
#  'CALAMUSPRORIDENS/NODOSUS-170210620': 'CALAMUS_PRORIDENS/NODOSUS',
#  'CALLIONYMIDAE-170420000': 'CALLIONYMIDAE',
#  'CANTHERHINESMACROCERUS-189040101': 'CANTHERHINES_MACROCERUS',
#  'CANTHERHINESPULLUS-189040102': 'CANTHERHINES_PULLUS',
#  'CANTHIDERMISMACULATUS-189030401': 'CANTHIDERMIS_MACULATUS',
#  'CANTHIDERMISSUFFLAMEN-189030402': 'CANTHIDERMIS_SUFFLAMEN',
#  'CANTHIGASTERJAMESTYLERI-189080102': 'CANTHIGASTER_JAMESTYLERI',
#  'CANTHIGASTERROSTRATUS-189080101': 'CANTHIGASTER_ROSTRATUS',
#  'CARANXBARTHOLOMAEI-170110801': 'CARANX_BARTHOLOMAEI',
#  'CARANXCRYSOS-170110803': 'CARANX_CRYSOS',
#  'CARANXHIPPOS-170110804': 'CARANX_HIPPOS',
#  'CARANXLATUS-170110805': 'CARANX_LATUS',
#  'CARANXLUGUBRIS-170110806': 'CARANX_LUGUBRIS',
#  'CARANXRUBER-170110807': 'CARANX_RUBER',
#  'GALEOCERDOCUVIERI-108022201': 'GALEOCERDO_CUVIERI',
#  'CAULOLATILUSCHRYSOPS-170070104': 'CAULOLATILUS_CHRYSOPS',
#  'CAULOLATILUSCYANOPS-170070101': 'CAULOLATILUS_CYANOPS',
#  'CAULOLATILUSINTERMEDIUS-170070102': 'CAULOLATILUS_INTERMEDIUS',
#  'CAULOLATILUSMICROPS-170070103': 'CAULOLATILUS_MICROPS',
#  'CENTROPRISTISFUSCULA': 'CENTROPRISTIS_FUSCULA',
#  'CENTROPRISTISOCYURA-170024804': 'CENTROPRISTIS_OCYURA',
#  'CENTROPRISTISPHILADELPHICA-170024805': 'CENTROPRISTIS_PHILADELPHICA',
#  'CENTROPRISTISSTRIATUS-170024806': 'CENTROPRISTIS_STRIATUS',
#  'CENTROPYGEARGI-170290301': 'CENTROPYGE_ARGI',
#  'CEPHALOPHOLISCRUENTATA-170020401': 'CEPHALOPHOLIS_CRUENTATA',
#  'CEPHALOPHOLISFULVA-170020403': 'CEPHALOPHOLIS_FULVA',
#  'CHAETODIPTERUSFABER-170250101': 'CHAETODIPTERUS_FABER',
#  'CHAETODONACULEATUS-170260305': 'CHAETODON_ACULEATUS',
#  'CHAETODONAYA-170260301': 'CHAETODON_AYA',
#  'CHAETODONCAPISTRATUS-170260302': 'CHAETODON_CAPISTRATUS',
#  'CHAETODONGUYANENSIS-170260304': 'CHAETODON_GUYANENSIS',
#  'CHAETODONOCELLATUS-170260307': 'CHAETODON_OCELLATUS',
#  'CHAETODONSEDENTARIUS-170260309': 'CHAETODON_SEDENTARIUS',
#  'CHAETODONSTRIATUS-170260310': 'CHAETODON_STRIATUS',
#  'CHROMISCYANEA-170270301': 'CHROMIS_CYANEA',
#  'CHROMISENCHRYSURUS-170270302': 'CHROMIS_ENCHRYSURUS',
#  'CHROMISINSOLATUS-170270304': 'CHROMIS_INSOLATUS',
#  'CHROMISMARGINATUS-170270305': 'CHROMIS_MARGINATUS',
#  'CHROMISMULTILINEATA-170270306': 'CHROMIS_MULTILINEATA',
#  'CHROMISSCOTTI-170270303': 'CHROMIS_SCOTTI',
#  'CLEPTICUSPARRAE-170283201': 'CLEPTICUS_PARRAE',
#  'COOKEOLUSJAPONICUS-170050302': 'COOKEOLUS_JAPONICUS',
#  'CORNIGERSPINOS-161110701': 'CORNIGER_SPINOS',
#  'CORYPHOPTERUSGLAUCOFRAENUM-170551004': 'CORYPHOPTERUS_GLAUCOFRAENUM',
#  'CORYPHOPTERUSTHRIX-170551009': 'CORYPHOPTERUS_THRIX',
#  'CRYPTOTOMUSROSEUS-170300601': 'CRYPTOTOMUS_ROSEUS',
#  'DECODONPUELLARIS-170283001': 'DECODON_PUELLARIS',
#  'DERMATOLEPISINERMIS-170020301': 'DERMATOLEPIS_INERMIS',
#  'DIODONHOLOCANTHUS-189090301': 'DIODON_HOLOCANTHUS',
#  'DIODONHYSTRIX-189090302': 'DIODON_HYSTRIX',
#  'DIPLECTRUMFORMOSUM-170020903': 'DIPLECTRUM_FORMOSUM',
#  'DIPLECTRUMBIVITTATUM-170020905': 'DIPLECTRUM_BIVITTATUM',
#  'ECHIOPHISPUNCTIFER-143150303': 'ECHIOPHIS_PUNCTIFER',
#  'ELAGATISBIPINNULATUS-170111301': 'ELAGATIS_BIPINNULATUS',
#  'EMBLEMARIAPANDIONIS-170370402': 'EMBLEMARIA_PANDIONIS',
#  'ENCHELYCORENIGRICANS-143060301': 'ENCHELYCORE_NIGRICANS',
#  'EPINEPHELUSADSCENSIONIS-170021203': 'EPINEPHELUS_ADSCENSIONIS',
#  'EPINEPHELUSDRUMMONDHAYI-170021205': 'EPINEPHELUS_DRUMMONDHAYI',
#  'EPINEPHELUSFLAVOLIMBATUS-170021206': 'EPINEPHELUS_FLAVOLIMBATUS',
#  'EPINEPHELUSGUTTATUS-170021208': 'EPINEPHELUS_GUTTATUS',
#  'EPINEPHELUSITAJARA-170021209': 'EPINEPHELUS_ITAJARA',
#  'EPINEPHELUSMORIO-170021211': 'EPINEPHELUS_MORIO',
#  'EPINEPHELUSMYSTACINUS-170021212': 'EPINEPHELUS_MYSTACINUS',
#  'EPINEPHELUSNIGRITUS-170021202': 'EPINEPHELUS_NIGRITUS',
#  'EPINEPHELUSNIVEATUS-170021201': 'EPINEPHELUS_NIVEATUS',
#  'EPINEPHELUSSTRIATUS-170021215': 'EPINEPHELUS_STRIATUS',
#  'EQUETUSACUMINATUS-170201103': 'EQUETUS_ACUMINATUS',
#  'EQUETUSIWAMOTOI-170201108': 'EQUETUS_IWAMOTOI',
#  'EQUETUSLANCEOLATUS-170201104': 'EQUETUS_LANCEOLATUS',
#  'EQUETUSPUNCTATUS-170201107': 'EQUETUS_PUNCTATUS',
#  'EQUETUSUMBROSUS-170201105': 'EQUETUS_UMBROSUS',
#  'ETELISOCULATUS-170150501': 'ETELIS_OCULATUS',
#  'EUTHYNNUSALLETTERATUS-170440201': 'EUTHYNNUS_ALLETTERATUS',
#  'EVERMANNICHTHYSSPONGICOLA-170554602': 'EVERMANNICHTHYS_SPONGICOLA',
#  'FISTULARIAPETIMBA-151020101': 'FISTULARIA_PETIMBA',
#  'FISTULARIATABACARIA-151020102': 'FISTULARIA_TABACARIA',
#  'GNATHOLEPISTHOMPSONI-170554401': 'GNATHOLEPIS_THOMPSONI',
#  'GOBIOSOMAHORSTI-170550204': 'GOBIOSOMA_HORSTI',
#  'GOBIOSOMAXANTHIPRORA-170550210': 'GOBIOSOMA_XANTHIPRORA',
#  'GOBULUSMEYERS-170551101': 'GOBULUS_MEYERS',
#  'GONIOPLECTRUSHISPANUS-170021403': 'GONIOPLECTRUS_HISPANUS',
#  'GYMNOTHORAXMORINGA-143060202': 'GYMNOTHORAX_MORINGA',
#  'GYMNOTHORAXSAXICOLA-143060205': 'GYMNOTHORAX_SAXICOLA',
#  'HAEMULONALBUM-170191002': 'HAEMULON_ALBUM',
#  'HAEMULONAUROLINEATUM-170191003': 'HAEMULON_AUROLINEATUM',
#  'HAEMULONCARBONARIUM-170191018': 'HAEMULON_CARBONARIUM',
#  'HAEMULONFLAVOLINEATUM-170191005': 'HAEMULON_FLAVOLINEATUM',
#  'HAEMULONMACROSTOMUM-170191017': 'HAEMULON_MACROSTOMUM',
#  'HAEMULONMELANURUM-170191007': 'HAEMULON_MELANURUM',
#  'HAEMULONPARRAI-170191014': 'HAEMULON_PARRAI',
#  'HAEMULONPLUMIERI-170191008': 'HAEMULON_PLUMIERI',
#  'HAEMULONSCIURUS-170191010': 'HAEMULON_SCIURUS',
#  'HAEMULONBONARIENSE-170191004': 'HAEMULON_BONARIENSE',
#  'HAEMULONBOSCHMAE-170191016': 'HAEMULON_BOSCHMAE',
#  'HAEMULONCHRYSARGYREUS-170191015': 'HAEMULON_CHRYSARGYREUS',
#  'HAEMULONLUTEUM-170191006': 'HAEMULON_LUTEUM',
#  'HAEMULONRIMATOR-170191009': 'HAEMULON_RIMATOR',
#  'HAEMULONSCUDDERI-170191011': 'HAEMULON_SCUDDERI',
#  'HAEMULONSTEINDACHNERI-170191012': 'HAEMULON_STEINDACHNERI',
#  'HAEMULONSTRIATUM-170191013': 'HAEMULON_STRIATUM',
#  'HALICHOERESRADIATUS-170281208': 'HALICHOERES_RADIATUS',
#  'HALICHOERESBATHYPHILUS-170281201': 'HALICHOERES_BATHYPHILUS',
#  'HALICHOERESBIVITTATUS-170281202': 'HALICHOERES_BIVITTATUS',
#  'HALICHOERESCAUDALIS-170281203': 'HALICHOERES_CAUDALIS',
#  'HALICHOERESCYANOCEPHALUS-170281210': 'HALICHOERES_CYANOCEPHALUS',
#  'HALICHOERESGARNOTI-170281205': 'HALICHOERES_GARNOTI',
#  'HALICHOERESMACULIPINNA-170281209': 'HALICHOERES_MACULIPINNA',
#  'HALICHOERESPICTUS-170281206': 'HALICHOERES_PICTUS',
#  'HALICHOERESPOEYI-170281207': 'HALICHOERES_POEYI',
#  'HEMANTHIASAUREORUBENS-170025003': 'HEMANTHIAS_AUREORUBENS',
#  'HEMANTHIASLEPTUS-170025002': 'HEMANTHIAS_LEPTUS',
#  'HEMANTHIASVIVANUS-170025001': 'HEMANTHIAS_VIVANUS',
#  'HEMIPTERONOTUSNOVACULA-170282903': 'HEMIPTERONOTUS_NOVACULA',
#  'HOLACANTHUSBERMUDENSIS-170290102': 'HOLACANTHUS_BERMUDENSIS',
#  'HOLACANTHUSCILIARIS-170290103': 'HOLACANTHUS_CILIARIS',
#  'HOLACANTHUSISABELITA-170290101': 'HOLACANTHUS_ISABELITA',
#  'HOLACANTHUSTRICOLOR-170290105': 'HOLACANTHUS_TRICOLOR',
#  'HOLANTHIUSMARTINICENSIS-170025101': 'HOLANTHIUS_MARTINICENSIS',
#  'HOLOCENTRUSADSCENSIONIS-161110201': 'HOLOCENTRUS_ADSCENSIONIS',
#  'HOLOCENTRUSRUFUS-161110202': 'HOLOCENTRUS_RUFUS',
#  'HOLOCENTRUSBULLISI-161110203': 'HOLOCENTRUS_BULLISI',
#  'HOLOCENTRUSCORUSCUS-161110204': 'HOLOCENTRUS_CORUSCUS',
#  'HOLOCENTRUSMARIANUS-161110207': 'HOLOCENTRUS_MARIANUS',
#  'HOLOCENTRUSPOCO-161110206': 'HOLOCENTRUS_POCO',
#  'HOLOCENTRUSVEXILLARIUS-161110205': 'HOLOCENTRUS_VEXILLARIUS',
#  'HYPOPLECTRUSPUELLA-170021502': 'HYPOPLECTRUS_PUELLA',
#  'HYPOPLECTRUSUNICOLOR-170021501': 'HYPOPLECTRUS_UNICOLOR',
#  'KAUPICHTHYSNUCHALIS-143040101': 'KAUPICHTHYS_NUCHALIS',
#  'KYPHOSUSINCISOR-170240301': 'KYPHOSUS_INCISOR',
#  'KYPHOSUSSECTATRIX-170240302': 'KYPHOSUS_SECTATRIX',
#  'LABRISOMUSHAITIENSIS-170370207': 'LABRISOMUS_HAITIENSIS',
#  'LACHNOLAIMUSMAXIMUS-170281801': 'LACHNOLAIMUS_MAXIMUS',
#  'LACTOPHRYSBICAUDALIS-189070201': 'LACTOPHRYS_BICAUDALIS',
#  'LACTOPHRYSPOLYGONIA-189070202': 'LACTOPHRYS_POLYGONIA',
#  'LACTOPHRYSQUADRICORNIS-189070203': 'LACTOPHRYS_QUADRICORNIS',
#  'LACTOPHRYSTRIGONUS-189070205': 'LACTOPHRYS_TRIGONUS',
#  'LACTOPHRYSTRIQUETER-189070206': 'LACTOPHRYS_TRIQUETER',
#  'LIOPROPOMAABERRANS-170025601': 'LIOPROPOMA_ABERRANS',
#  'LIOPROPOMAEUKRINES-170025602': 'LIOPROPOMA_EUKRINES',
#  'LOPHOLATILUSCHAMAELEONTICEPS-170070201': 'LOPHOLATILUS_CHAMAELEONTICEPS',
#  'LUTJANUSANALIS-170151101': 'LUTJANUS_ANALIS',
#  'LUTJANUSAPODUS-170151102': 'LUTJANUS_APODUS',
#  'LUTJANUSBUCCANELA-170151106': 'LUTJANUS_BUCCANELA',
#  'LUTJANUSCAMPECHANUS-170151107': 'LUTJANUS_CAMPECHANUS',
#  'LUTJANUSCYANOPTERUS-170151108': 'LUTJANUS_CYANOPTERUS',
#  'LUTJANUSGRISEUS-170151109': 'LUTJANUS_GRISEUS',
#  'LUTJANUSJOCU-170151111': 'LUTJANUS_JOCU',
#  'LUTJANUSMAHOGONI-170151115': 'LUTJANUS_MAHOGONI',
#  'LUTJANUSSYNAGRIS-170151113': 'LUTJANUS_SYNAGRIS',
#  'LUTJANUSVIVANUS-170151114': 'LUTJANUS_VIVANUS',
#  'LYTHRYPNUSNESIOTES-170551301': 'LYTHRYPNUS_NESIOTES',
#  'LYTHRYPNUSPHORELLUS-170551302': 'LYTHRYPNUS_PHORELLUS',
#  'LYTHRYPNUSSPILUS-170551303': 'LYTHRYPNUS_SPILUS',
#  'MALACANTHUSPLUMIERI-170070301': 'MALACANTHUS_PLUMIERI',
#  'MELICHTHYSNIGER-189030301': 'MELICHTHYS_NIGER',
#  'MICROSPATHODONCHRYSURUS-170270201': 'MICROSPATHODON_CHRYSURUS',
#  'MULLOIDICHTHYSMARTINICUS-170220101': 'MULLOIDICHTHYS_MARTINICUS',
#  'MULLUSAURATUS-170220203': 'MULLUS_AURATUS',
#  'MURAENARETIFERA-143060402': 'MURAENA_RETIFERA',
#  'MYCTEROPERCAACUTIROSTRIS-170022109': 'MYCTEROPERCA_ACUTIROSTRIS',
#  'MYCTEROPERCABONACI-170022101': 'MYCTEROPERCA_BONACI',
#  'MYCTEROPERCAINTERSTITIALIS-170022103': 'MYCTEROPERCA_INTERSTITIALIS',
#  'MYCTEROPERCAMICROLEPIS-170022104': 'MYCTEROPERCA_MICROLEPIS',
#  'MYCTEROPERCAPHENAX-170022105': 'MYCTEROPERCA_PHENAX',
#  'MYCTEROPERCATIGRIS-170022106': 'MYCTEROPERCA_TIGRIS',
#  'MYCTEROPERCAVENENOSA-170022107': 'MYCTEROPERCA_VENENOSA',
#  'MYCTEROPERCAINTERSTITIALIS/PHENAX-999910100': 'MYCTEROPERCA_INTERSTITIALIS/PHENAX',
#  'MYRIPRISTISJACOBUS-161110501': 'MYRIPRISTIS_JACOBUS',
#  'NEONIPHONMARIANUS': 'NEONIPHON_MARIANUS',
#  'OCYURUSCHRYSURUS-170151501': 'OCYURUS_CHRYSURUS',
#  'ODONTOSCIONDENTEX-170202201': 'ODONTOSCION_DENTEX',
#  'OPHICHTHUSPUNCTICEPS-143150402': 'OPHICHTHUS_PUNCTICEPS',
#  'OPHIOBLENNIUSATLANTICUS-170362001': 'OPHIOBLENNIUS_ATLANTICUS',
#  'OPISTOGNATHUSLONCHURUS-170310201': 'OPISTOGNATHUS_LONCHURUS',
#  'OPISTOGNATHUSMAXILLOSUS-170310202': 'OPISTOGNATHUS_MAXILLOSUS',
#  'ORTHOPRISTISCHRYSOPTERUS-170191702': 'ORTHOPRISTIS_CHRYSOPTERUS',
#  'OSTICHTHYSTRACHYPOMUS-161110601': 'OSTICHTHYS_TRACHYPOMUS',
#  'PAGRUSPAGRUS-170212302': 'PAGRUS_PAGRUS',
#  'PARABLENNIUSMARMOREUS-170360601': 'PARABLENNIUS_MARMOREUS',
#  'PARACONGERCAUDILIMBATUS-143131502': 'PARACONGER_CAUDILIMBATUS',
#  'PARANTHIASFURCIFER-170022701': 'PARANTHIAS_FURCIFER',
#  'PLECTANTHIASGARRUPELLUS': 'PLECTANTHIAS_GARRUPELLUS',
#  'PLECTRYPOPSRETROSPINUS-161110801': 'PLECTRYPOPS_RETROSPINUS',
#  'POMACANTHUSARCUATUS-170290201': 'POMACANTHUS_ARCUATUS',
#  'POMACANTHUSPARU-170290203': 'POMACANTHUS_PARU',
#  'POMACENTRUSFUSCUS-170270505': 'POMACENTRUS_FUSCUS',
#  'POMACENTRUSLEUCOSTEUS-170270501': 'POMACENTRUS_LEUCOSTEUS',
#  'POMACENTRUSPARTITUS-170270502': 'POMACENTRUS_PARTITUS',
#  'POMACENTRUSPICTUS-170270503': 'POMACENTRUS_PICTUS',
#  'POMACENTRUSPLANIFRONS-170270506': 'POMACENTRUS_PLANIFRONS',
#  'POMACENTRUSVARIABILIS-170270504': 'POMACENTRUS_VARIABILIS',
#  'POMATOMUSSALTATRIX-170080101': 'POMATOMUS_SALTATRIX',
#  'PRIACANTHUSARENATUS-170050101': 'PRIACANTHUS_ARENATUS',
#  'PRIACANTHUSCRUENTATUS-170050102': 'PRIACANTHUS_CRUENTATUS',
#  'PRISTIGENYSALTA-170050401': 'PRISTIGENYS_ALTA',
#  'PRISTIPOMOIDESAQUILONARIS-170151802': 'PRISTIPOMOIDES_AQUILONARIS',
#  'PSEUDUPENEUSMACULATUS-170220701': 'PSEUDUPENEUS_MACULATUS',
#  'PTERELEOTRIS': 'PTERELEOTRIS',
#  'PTEROIS-168011900': 'PTEROIS',
#  'PTEROISMILES-168011902': 'PTEROIS_MILES',
#  'PTEROISVOLITANS-168011901': 'PTEROIS_VOLITANS',
#  'RACHYCENTRONCANADUM-170100101': 'RACHYCENTRON_CANADUM',
#  'RHOMBOPLITESAURORUBENS-170152001': 'RHOMBOPLITES_AURORUBENS',
#  'RYPTICUSSUBBIFRENATUS-170030109': 'RYPTICUS_SUBBIFRENATUS',
#  'SCARUSCOELESTINUS-170301101': 'SCARUS_COELESTINUS',
#  'SCARUSCOERULEUS-170301104': 'SCARUS_COERULEUS',
#  'SCARUSGUACAMAIA-170301105': 'SCARUS_GUACAMAIA',
#  'SCARUSTAENIOPTERUS-170301106': 'SCARUS_TAENIOPTERUS',
#  'SCARUSVETULA-170301107': 'SCARUS_VETULA',
#  'SCARUSCROICENSIS-170301103': 'SCARUS_CROICENSIS',
#  'SCOMBEROMORUSCAVALLA-170440801': 'SCOMBEROMORUS_CAVALLA',
#  'SCOMBEROMORUSMACULATUS-170440803': 'SCOMBEROMORUS_MACULATUS',
#  'SCOMBEROMORUSREGALIS-170440804': 'SCOMBEROMORUS_REGALIS',
#  'SCORPAENAPLUMIERI-168010712': 'SCORPAENA_PLUMIERI',
#  'SELENEVOMER-170113003': 'SELENE_VOMER',
#  'SERIOLADUMERILI-170113101': 'SERIOLA_DUMERILI',
#  'SERIOLAFASCIATA-170113103': 'SERIOLA_FASCIATA',
#  'SERIOLARIVOLIANA-170113105': 'SERIOLA_RIVOLIANA',
#  'SERIOLAZONATA-170113106': 'SERIOLA_ZONATA',
#  'SERRANUSANNULARIS-170024201': 'SERRANUS_ANNULARIS',
#  'SERRANUSATROBRANCHUS-170024202': 'SERRANUS_ATROBRANCHUS',
#  'SERRANUSCHIONARAIA-170024205': 'SERRANUS_CHIONARAIA',
#  'SERRANUSNOTOSPILUS-170024207': 'SERRANUS_NOTOSPILUS',
#  'SERRANUSSUBLIGARIUS-170024209': 'SERRANUS_SUBLIGARIUS',
#  'SERRANUSTABACARIUS-170024210': 'SERRANUS_TABACARIUS',
#  'SERRANUSTIGRINUS-170024214': 'SERRANUS_TIGRINUS',
#  'SERRANUSPHOEBE-170024208': 'SERRANUS_PHOEBE',
#  'SPARISOMACHRYSOPTERUM-170301202': 'SPARISOMA_CHRYSOPTERUM',
#  'SPARISOMARUBRIPINNE-170301204': 'SPARISOMA_RUBRIPINNE',
#  'SPARISOMAVIRIDE-170301206': 'SPARISOMA_VIRIDE',
#  'SPARISOMAATROMARIUM-170301205': 'SPARISOMA_ATROMARIUM',
#  'SPARISOMAAUROFRENATUM-170301201': 'SPARISOMA_AUROFRENATUM',
#  'SPARISOMARADIANS-170301203': 'SPARISOMA_RADIANS',
#  'SPHYRAENABARRACUDA-165030101': 'SPHYRAENA_BARRACUDA',
#  'STENOCIONOPSSPINIMANA-229211803': 'STENOCIONOPS_SPINIMANA',
#  'SYNODUSSYNODUS-129040306': 'SYNODUS_SYNODUS',
#  'THALASSOMABIFASCIATUM-170282801': 'THALASSOMA_BIFASCIATUM',
#  'TRACHINOCEPHALUSMYOPS-129040101': 'TRACHINOCEPHALUS_MYOPS',
#  'TRACHINOTUSCAROLINUS-170113601': 'TRACHINOTUS_CAROLINUS',
#  'TRACHINOTUSFALCATUS-170113603': 'TRACHINOTUS_FALCATUS',
#  'UPENEUSPARVUS-170220605': 'UPENEUS_PARVUS',
#  'URASPISSECUNDA-170114202': 'URASPIS_SECUNDA',
#  'UROPHYCISREGIA-148010105': 'UROPHYCIS_REGIA',
#  'XANTHICHTHYSRINGENS-189030101': 'XANTHICHTHYS_RINGENS',
#  'ACANTHOSTRACIONQUADRICORNIS-189070101': 'ACANTHOSTRACION_QUADRICORNIS',
#  'ACANTHURUS-170160100': 'ACANTHURUS',
#  'ALUTERUSMONOCEROS-189040402': 'ALUTERUS_MONOCEROS',
#  'ALUTERUSSCHOEPFI-189040403': 'ALUTERUS_SCHOEPFI',
#  'ALUTERUSSCRIPTUS-189040404': 'ALUTERUS_SCRIPTUS',
#  'ALUTERUS-189040400': 'ALUTERUS',
#  'AMPHINOMIDAE-649110000': 'AMPHINOMIDAE',
#  'ANOMURA-999100401': 'ANOMURA',
#  'ANTENNARIUS-195020100': 'ANTENNARIUS',
#  'ANTHIAS-170026000': 'ANTHIAS',
#  'ANTHIINAE-999020300': 'ANTHIINAE',
#  'APOGON-170060200': 'APOGON',
#  'ASTEROIDEA-691000000': 'ASTEROIDEA',
#  'BALISTES-189030500': 'BALISTES',
#  'BALISTIDAE-189030000': 'BALISTIDAE',
#  'BLENNIIDAE-170360000': 'BLENNIIDAE',
#  'BRACHYURA-999100402': 'BRACHYURA',
#  'CALAMUS-170210600': 'CALAMUS',
#  'CANTHERHINES-189040100': 'CANTHERHINES',
#  'CANTHIGASTERROSTRATA-189080101': 'CANTHIGASTER_ROSTRATA',
#  'CARANGIDAE-170110000': 'CARANGIDAE',
#  'CARANX-170110800': 'CARANX',
#  'CARCHARHINIDAE-108020000': 'CARCHARHINIDAE',
#  'CARCHARHINIFORMES-108000000': 'CARCHARHINIFORMES',
#  'CARCHARHINUSBREVIPINNA-108020207': 'CARCHARHINUS_BREVIPINNA',
#  'CARCHARHINUSFALCIFORMIS-108020202': 'CARCHARHINUS_FALCIFORMIS',
#  'CARCHARHINUSLEUCAS-108020204': 'CARCHARHINUS_LEUCAS',
#  'CARCHARHINUSLIMBATUS-108020205': 'CARCHARHINUS_LIMBATUS',
#  'CARCHARHINUSPEREZI-108020211': 'CARCHARHINUS_PEREZI',
#  'CARCHARHINUSPLUMBEUS-108020208': 'CARCHARHINUS_PLUMBEUS',
#  'CARCHARHINUS-108020200': 'CARCHARHINUS',
#  'CENTROPRISTISOCYURUS-170024804': 'CENTROPRISTIS_OCYURUS',
#  'CHAETODON-170260300': 'CHAETODON',
#  'CHROMIS-170270300': 'CHROMIS',
#  'CORYPHOPTERUS-170551000': 'CORYPHOPTERUS',
#  'DASYATIS-110050200': 'DASYATIS',
#  'DASYATISAMERICANUS-110050201': 'DASYATIS_AMERICANUS',
#  'DECAPODA-227000000': 'DECAPODA',
#  'DECAPTERUS-170111200': 'DECAPTERUS',
#  'DIODON-189090300': 'DIODON',
#  'DIPLECTRUM-170020900': 'DIPLECTRUM',
#  'ECHENEIS-170090100': 'ECHENEIS',
#  'ECHIOPHIS-143150300': 'ECHIOPHIS',
#  'EMBLEMARIA-170370400': 'EMBLEMARIA',
#  'EPINEPHELUS-170021200': 'EPINEPHELUS',
#  'EQUETUS-170201100': 'EQUETUS',
#  'FISTULARIA-151020100': 'FISTULARIA',
#  'GALATHEOIDEA-999100406': 'GALATHEOIDEA',
#  'GINGLYMOSTOMACIRRATUM-113010101': 'GINGLYMOSTOMA_CIRRATUM',
#  'GOBIIDAE-170550000': 'GOBIIDAE',
#  'HAEMULON-170191000': 'HAEMULON',
#  'HALICHOERES-170281200': 'HALICHOERES',
#  'HEMANTHIAS-170025000': 'HEMANTHIAS',
#  'HOLACANTHUS-170290100': 'HOLACANTHUS',
#  'HOLOCENTRUS-161110200': 'HOLOCENTRUS',
#  'HYPOPLECTRUSGEMMA-170021503': 'HYPOPLECTRUS_GEMMA',
#  'HYPOPLECTRUSNIGRICANS-170021506': 'HYPOPLECTRUS_NIGRICANS',
#  'HYPOPLECTRUS-170021500': 'HYPOPLECTRUS',
#  'HYPORTHODUSFLAVOLIMBATUS-170021206': 'HYPORTHODUS_FLAVOLIMBATUS',
#  'IOGLOSSUSCALLIURUS-170550801': 'IOGLOSSUS_CALLIURUS',
#  'IOGLOSSUS-170550800': 'IOGLOSSUS',
#  'KYPHOSUS-170240300': 'KYPHOSUS',
#  'LABRIDAE-170280000': 'LABRIDAE',
#  'LABROIDEI-999010400': 'LABROIDEI',
#  'LACTOPHRYS-189070200': 'LACTOPHRYS',
#  'LIBINIA-229080100': 'LIBINIA',
#  'LIOPROPOMAMOWBRAYI-170025603': 'LIOPROPOMA_MOWBRAYI',
#  'LUTJANUS-170151100': 'LUTJANUS',
#  'MONACANTHIDAE-189040000': 'MONACANTHIDAE',
#  'MONACANTHUSTUCKERI-189040203': 'MONACANTHUS_TUCKERI',
#  'MULLIDAE-170220000': 'MULLIDAE',
#  'MUSTELUS-108031100': 'MUSTELUS',
#  'MYCTEROPERCA-170022100': 'MYCTEROPERCA',
#  'MYLIOBATIFORMES-999002001': 'MYLIOBATIFORMES',
#  'OPHICHTHUSREX-143150407': 'OPHICHTHUS_REX',
#  'OPISTOGNATHUSAURIFRONS-170310203': 'OPISTOGNATHUS_AURIFRONS',
#  'OPISTOGNATHUS-170310200': 'OPISTOGNATHUS',
#  'PAREQUESUMBROSUS-170201105': 'PAREQUES_UMBROSUS',
#  'POMACANTHUS-170290200': 'POMACANTHUS',
#  'POMACENTRIDAE-170270000': 'POMACENTRIDAE',
#  'POMACENTRUS-170270500': 'POMACENTRUS',
#  'PORTUNUS-229110800': 'PORTUNUS',
#  'PRIACANTHUS-170050100': 'PRIACANTHUS',
#  'PRISTIPOMOIDES-170151800': 'PRISTIPOMOIDES',
#  'PROGNATHODESAYA-170260301': 'PROGNATHODES_AYA',
#  'PRONOTOGRAMMUSMARTINICENSIS-170025101': 'PRONOTOGRAMMUS_MARTINICENSIS',
#  'SCAD-999910200': 'SCAD',
#  'SCARIDAE-170300000': 'SCARIDAE',
#  'SCARUS-170301100': 'SCARUS',
#  'SCOMBEROMORUS-170440800': 'SCOMBEROMORUS',
#  'SCOMBRIDAE-170440000': 'SCOMBRIDAE',
#  'SERIOLA-170113100': 'SERIOLA',
#  'SERRANIDAE-170020000': 'SERRANIDAE',
#  'SERRANUSTORTUGARUM-170024211': 'SERRANUS_TORTUGARUM',
#  'SERRANUS-170024200': 'SERRANUS',
#  'SPARIDAE-170210000': 'SPARIDAE',
#  'SPARISOMA-170301200': 'SPARISOMA',
#  'SPHOEROIDESSPENGLERI-189080610': 'SPHOEROIDES_SPENGLERI',
#  'SPHOEROIDES-189080600': 'SPHOEROIDES',
#  'SPHYRNALEWINI-108040102': 'SPHYRNA_LEWINI',
#  'SPHYRNAMOKARRAN-108040103': 'SPHYRNA_MOKARRAN',
#  'SPHYRNATIBURO-108040104': 'SPHYRNA_TIBURO',
#  'STENOTOMUSCAPRINUS-170213403': 'STENOTOMUS_CAPRINUS',
#  'STEPHANOLEPISHISPIDA-189040305': 'STEPHANOLEPIS_HISPIDA',
#  'STEPHANOLEPISINSIGNIS-189040302': 'STEPHANOLEPIS_INSIGNIS',
#  'STEPHANOLEPISSETIFER-189040303': 'STEPHANOLEPIS_SETIFER',
#  'STEPHANOLEPISVAIRUS-189040304': 'STEPHANOLEPIS_VAIRUS',
#  'SYACIUM-183011000': 'SYACIUM',
#  'SYNODONTIDAE-129040000': 'SYNODONTIDAE',
#  'SYNODUS-129040300': 'SYNODUS',
#  'DIODONTIDAE-189090000': 'DIODONTIDAE',
#  'CORYPHAENAHIPPURUS-170130202': 'CORYPHAENA_HIPPURUS',
#  'MAKAIRANIGRICANS-170470201': 'MAKAIRA_NIGRICANS',
#  'ISTIOPHORUSALBICANS-170470104': 'ISTIOPHORUS_ALBICANS',
#  'TETRAPTURUSALBIDUS-170470301': 'TETRAPTURUS_ALBIDUS',
#  'ACANTHOCYBIUMSOLANDRI-170440901': 'ACANTHOCYBIUM_SOLANDRI',
#  'THUNNUSALBACARES-170440402': 'THUNNUS_ALBACARES',
#  'THUNNUSTHYNNUS-170440405': 'THUNNUS_THYNNUS',
#  'THUNNUSATLANTICUS-170440403': 'THUNNUS_ATLANTICUS',
#  'SARDASARDA-170440701': 'SARDA_SARDA',
#  'RYPTICUSMACULATUS-170030106': 'RYPTICUS_MACULATUS',
#  'KATSUWONUSPELAMIS-170440301': 'KATSUWONUS_PELAMIS',
#  'UNKNOWNFISH': 'CHORDATA',
#  'SCHOOL': 'CHORDATA',
#  'HYPORTHODUSNIGRITUS-170021202': 'HYPORTHODUS_NIGRITUS'}

# %%
new_categories = {}
failed_categories = []
for cat in observed_categories:
    try:
        new_categories[cat] = name_map[cat]
    except:
        failed_categories.append(cat)
assert not failed_categories

# %% [raw]
# CANTHIGASTERROSTRATA  Canthigaster rostrata
#
# PRONOTOGRAMMUSMARTINICENSIS  Pronotogrammus martinicensis   https://marinespecies.org/aphia.php?p=taxdetails&id=282365
# PRONOTOGRAMMUSMARTINICENSIS used to be HOLANTHIAS_MARTINICENSIS
#
# PROGNATHODESAYA   Prognathodes aya
#
# HYPORTHODUSFLAVOLIMBATUS    Hyporthodus flavolimbatus   https://www.marinespecies.org/aphia.php?p=taxdetails&id=475077
# HYPORTHODUSFLAVOLIMBATUS used to be EPINEPHELUS_FLAVOLIMBATUS
#
# MONACANTHUSTUCKERI   Monacanthus tuckeri   https://www.marinespecies.org/aphia.php?p=taxdetails&id=159499
#
# SCHOOL   Animalia
#
# CENTROPRISTISOCYURUS   Centropristis ocyurus    https://www.marinespecies.org/aphia.php?p=taxdetails&id=159346
# And for some reason VIAME misspells CENTROPRISTIS_OCYURUS into CENTROPRISTIS_OCYURA
#
# PRISTIPOMOIDES    Pristipomoides    https://www.marinespecies.org/aphia.php?p=taxdetails&id=159804
#
# PAREQUESUMBROSUS    Pareques umbrosus    https://www.marinespecies.org/aphia.php?p=taxdetails&id=282143
# PAREQUESUMBROSUS used to be EQUETUS_UMBROSUS

# %% [markdown]
# ## Other updates

# %% [markdown]
# ### Updating "crowd" type categories to have the "iscrowd" attribute
#
# "SCHOOL" and possibly others are "crowd" type categories.

# %%
crowd_categories = set(["SCHOOL"])
crowd_category_ids = set([cat["id"] for cat in raw_coco["categories"] if cat["name"] in crowd_categories])
for ann in raw_coco["annotations"]:
    if ann["id"] in crowd_category_ids:
        ann["iscrowd"] = 1
crowd_category_ids
# Out:
# {114}

# %%
import pyworms
import requests
import re
from urllib.parse import quote

import pyworms
import re
from difflib import SequenceMatcher

class TaxonomyPipeline:
    def __init__(self):
        # Regex to strip open nomenclature (sp, spp, complex, etc.)
        self.suffix_regex = re.compile(r'\s+(sp\.|spp\.|complex|s\.l\.|cf\.|var\.|subsp\.)', re.IGNORECASE)
        
        # Base URL for WoRMS REST API (Kept for reference, though we use pyworms mostly)
        self.WORMS_API_URL = "https://www.marinespecies.org/rest/AphiaRecordsByName"

    def resolve(self, moniker):
        result = {
            "original": moniker,
            "status": "UNRESOLVED",
            "accepted_name": None,
            "aphia_id": None,
            "candidates": [],
            "notes": ""
        }

        # --- Attempt 1: Exact Lookup (Safe & Fast) ---
        match = self._query_worms_exact(moniker)
        if match:
            return self._format_result(result, match, "RESOLVED")

        # --- Attempt 2: Parent Lookup (Safe & Fast) ---
        clean_name, cleaned = self._clean_name(moniker)
        if cleaned:
            match = self._query_worms_exact(clean_name)
            if match:
                res = self._format_result(result, match, "PARTIAL")
                res["notes"] = f"Stripped suffix: '{moniker}' -> '{clean_name}'"
                return res

        # --- Attempt 3: Smart Genus Search (The Fix for 'spinimana') ---
        # Logic: If standard lookup failed, pull the Genus and look for close spellings
        # This fixes "Stenocionops spinimana" (invalid) -> "Stenocionops spinimanus" (valid)
        genus_candidates = self._smart_genus_match(moniker)
        if genus_candidates:
            result["status"] = "AMBIGUOUS"
            result["candidates"] = genus_candidates
            result["notes"] = "Found similar species in same Genus (Latin ending fix?)"
            return result

        # --- Attempt 4: Single-Page Fuzzy Search ---
        # We manually call the API to get page 1 only.
        candidates = self._fuzzy_search(clean_name)
        if candidates:
            result["status"] = "AMBIGUOUS"
            result["candidates"] = candidates
            result["notes"] = f"Ambiguous. Found {len(candidates)} candidates (Page 1)."
            return result

        result["notes"] = "No biological match found."
        return result

    def _query_worms_exact(self, name):
        """Uses pyworms library for exact matching."""
        try:
            res = pyworms.aphiaRecordsByName(name, like=False)
            if res and len(res) > 0:
                return res[0]
        except Exception:
            pass
        return None

    def _smart_genus_match(self, name):
        """
        Splits 'Genus species', queries the Genus, and checks for spelling proximity.
        """
        parts = name.split()
        if len(parts) < 2: 
            return [] # Not a binomial name

        genus = parts[0]
        epithet = parts[1] # e.g., 'spinimana'

        try:
            # 1. Get all species in this Genus (using 'like' on the Genus name)
            # We search "Genus%" to get the children.
            # marine_only=True speeds this up significantly.
            genus_records = pyworms.aphiaRecordsByName(genus + '%', like=True, marine_only=True)
            
            if not genus_records:
                return []

            candidates = []
            seen_names = set()

            for rec in genus_records:
                valid_name = rec.get('valid_name')
                if not valid_name or valid_name in seen_names:
                    continue
                
                # Verify it is actually in this genus (fuzzy search can return similar genera)
                if not valid_name.startswith(genus):
                    continue

                seen_names.add(valid_name)

                # 2. Compare the species part (Epithet)
                target_parts = valid_name.split()
                if len(target_parts) < 2: continue
                
                target_epithet = target_parts[1]

                # 3. Calculate similarity score (0.0 to 1.0)
                # This catches 'spinimana' vs 'spinimanus' (high score)
                similarity = SequenceMatcher(None, epithet, target_epithet).ratio()
                
                # Threshold > 0.80 usually catches gender endings without false positives
                if similarity > 0.80:
                    candidates.append(valid_name)
            
            return candidates[:5] # Return top 5 matches

        except Exception:
            pass
        return []

    def _fuzzy_search(self, name):
        """
        Fuzzy lookup using pyworms. 
        Note: pyworms does NOT loop. It returns Page 1 (first 50 items) only.
        """
        try:
            # Add wildcard '%' to the end for the search
            res = pyworms.aphiaRecordsByName(name + '%', like=True, marine_only=True)
            if res:
                # Return distinct valid names
                return list(set([r['valid_name'] for r in res]))
        except Exception:
            pass
        return []

    def _clean_name(self, name):
        match = self.suffix_regex.search(name)
        if match:
            return name[:match.start()], True
        return name, False

    def _format_result(self, result, record, status):
        result["status"] = status
        result["accepted_name"] = record.get('valid_name', 'N/A')
        result["aphia_id"] = record.get('valid_AphiaID', record.get('AphiaID'))
        
        if record.get('status') == 'unaccepted':
             result["notes"] += f" [Synonym: {record.get('scientificname')} -> {record.get('valid_name')}]"
        return result

# %%
pipeline = TaxonomyPipeline()

# %% [raw]
# inputs = [
#     "Bathochordaeus",            # Easy
#     "Loligo opalescens",         # Synonym (Should auto-resolve to Doryteuthis)
#     "Sebastes sp.",              # Parent Match
#     "Gorgonocephalus complex",   # Parent Match
#     "Deep sea jelly",            # Ambiguous (Needs HITL)
#     "Marine debris",             # Unresolved (Non-bio)
#     "Alien spaceship"            # Unresolved (Nonsense)
# ]

# %% [raw]
# list(map(pipeline._clean_name, inputs))

# %% [raw]
# print(f"{'Input':<25} | {'Status':<12} | {'Accepted Name':<25} | {'AphiaID':<8}")
# print("-" * 100)
#
# for m in inputs:
#     res = pipeline.resolve(m)
#     aphia = str(res['aphia_id']) if res['aphia_id'] else "---"
#     name = res['accepted_name'] if res['accepted_name'] else "---"
#
#     print(f"{m:<25} | {res['status']:<12} | {name:<25} | {aphia:<8}")
#
#     # If Ambiguous, show candidates for the UI
#     if res['status'] == 'AMBIGUOUS':
#         print(f"   >>> ACTION: User must choose from: {res['candidates'][:3]}...")
#
#     # If Unresolved, flag for manual entry
#     if res['status'] == 'UNRESOLVED':
#         print(f"   >>> ACTION: Manual Entry Required.")

# %%
full_map = {}
if not REFRESH:
    with open('worms_map.csv') as f:
        reader = csv.reader(f)
        header = next(reader)
        full_map = dict(reader)

# %%
new_categories.keys() - full_map.keys()
# Out:
# {'ALBULAVULPES-121030101',
#  'ALECTISCILIARIS-170110101',
#  'ANISOTREMUSVIRGINICUS-170190105',
#  'ANOMURA-999100401',
#  'ANTHIINAE-999020300',
#  'ARCHOSARGUSPROBATOCEPHALUS-170213601',
#  'BALISTESCAPRISCUS-189030502',
#  'BALISTESVETULA-189030504',
#  'BODIANUSPULCHELLUS-170280201',
#  'BODIANUSRUFUS-170280202',
#  'CALAMUS-170210600',
#  'CALAMUSBAJONADO-170210602',
#  'CALAMUSLEUCOSTEUS-170210604',
#  'CALAMUSNODOSUS-170210608',
#  'CALAMUSPRORIDENS-170210605',
#  'CALLIONYMIDAE-170420000',
#  'CANTHIDERMISSUFFLAMEN-189030402',
#  'CANTHIGASTERJAMESTYLERI-189080102',
#  'CANTHIGASTERROSTRATA-189080101',
#  'CARANGIDAE-170110000',
#  'CARANXBARTHOLOMAEI-170110801',
#  'CARANXCRYSOS-170110803',
#  'CARANXRUBER-170110807',
#  'CARCHARHINUS-108020200',
#  'CARCHARHINUSFALCIFORMIS-108020202',
#  'CARCHARHINUSPLUMBEUS-108020208',
#  'CAULOLATILUSCHRYSOPS-170070104',
#  'CAULOLATILUSCYANOPS-170070101',
#  'CAULOLATILUSMICROPS-170070103',
#  'CENTROPRISTISOCYURUS-170024804',
#  'CENTROPRISTISPHILADELPHICA-170024805',
#  'CEPHALOPHOLISCRUENTATA-170020401',
#  'CHAETODIPTERUSFABER-170250101',
#  'CHAETODON-170260300',
#  'CHAETODONCAPISTRATUS-170260302',
#  'CHAETODONOCELLATUS-170260307',
#  'CHAETODONSEDENTARIUS-170260309',
#  'CHROMIS-170270300',
#  'CHROMISENCHRYSURUS-170270302',
#  'CHROMISINSOLATUS-170270304',
#  'DECAPTERUS-170111200',
#  'DECODONPUELLARIS-170283001',
#  'DERMATOLEPISINERMIS-170020301',
#  'DIPLECTRUMFORMOSUM-170020903',
#  'EPINEPHELUS-170021200',
#  'EPINEPHELUSADSCENSIONIS-170021203',
#  'EPINEPHELUSMORIO-170021211',
#  'GOBIIDAE-170550000',
#  'GONIOPLECTRUSHISPANUS-170021403',
#  'GYMNOTHORAXMORINGA-143060202',
#  'GYMNOTHORAXSAXICOLA-143060205',
#  'HAEMULONALBUM-170191002',
#  'HAEMULONAUROLINEATUM-170191003',
#  'HALICHOERES-170281200',
#  'HALICHOERESBATHYPHILUS-170281201',
#  'HALICHOERESBIVITTATUS-170281202',
#  'HOLACANTHUS-170290100',
#  'HOLACANTHUSBERMUDENSIS-170290102',
#  'HOLOCENTRUS-161110200',
#  'HOLOCENTRUSADSCENSIONIS-161110201',
#  'HYPOPLECTRUS-170021500',
#  'HYPORTHODUSFLAVOLIMBATUS-170021206',
#  'HYPORTHODUSNIGRITUS-170021202',
#  'IOGLOSSUS-170550800',
#  'LACHNOLAIMUSMAXIMUS-170281801',
#  'LIOPROPOMAEUKRINES-170025602',
#  'LUTJANUS-170151100',
#  'LUTJANUSANALIS-170151101',
#  'LUTJANUSAPODUS-170151102',
#  'LUTJANUSCAMPECHANUS-170151107',
#  'LUTJANUSGRISEUS-170151109',
#  'LUTJANUSSYNAGRIS-170151113',
#  'LUTJANUSVIVANUS-170151114',
#  'MALACANTHUSPLUMIERI-170070301',
#  'MONACANTHUSTUCKERI-189040203',
#  'MULLIDAE-170220000',
#  'MURAENARETIFERA-143060402',
#  'MYCTEROPERCA-170022100',
#  'MYCTEROPERCABONACI-170022101',
#  'MYCTEROPERCAINTERSTITIALIS-170022103',
#  'MYCTEROPERCAMICROLEPIS-170022104',
#  'MYCTEROPERCAPHENAX-170022105',
#  'OPHICHTHUSPUNCTICEPS-143150402',
#  'OPISTOGNATHUS-170310200',
#  'OPISTOGNATHUSAURIFRONS-170310203',
#  'OSTICHTHYSTRACHYPOMUS-161110601',
#  'PAGRUSPAGRUS-170212302',
#  'PARANTHIASFURCIFER-170022701',
#  'PAREQUESUMBROSUS-170201105',
#  'POMACANTHUSARCUATUS-170290201',
#  'POMACANTHUSPARU-170290203',
#  'POMACENTRIDAE-170270000',
#  'PRIACANTHUSARENATUS-170050101',
#  'PRISTIGENYSALTA-170050401',
#  'PRISTIPOMOIDES-170151800',
#  'PROGNATHODESAYA-170260301',
#  'PRONOTOGRAMMUSMARTINICENSIS-170025101',
#  'PTEROIS-168011900',
#  'RHOMBOPLITESAURORUBENS-170152001',
#  'SCHOOL',
#  'SCOMBEROMORUS-170440800',
#  'SCOMBEROMORUSMACULATUS-170440803',
#  'SELENEVOMER-170113003',
#  'SERIOLA-170113100',
#  'SERIOLADUMERILI-170113101',
#  'SERIOLAFASCIATA-170113103',
#  'SERIOLARIVOLIANA-170113105',
#  'SERIOLAZONATA-170113106',
#  'SERRANUS-170024200',
#  'SERRANUSANNULARIS-170024201',
#  'SERRANUSATROBRANCHUS-170024202',
#  'SERRANUSPHOEBE-170024208',
#  'SERRANUSSUBLIGARIUS-170024209',
#  'SERRANUSTORTUGARUM-170024211',
#  'SPHYRAENABARRACUDA-165030101',
#  'SPHYRNALEWINI-108040102',
#  'STENOCIONOPSSPINIMANA-229211803',
#  'STENOTOMUSCAPRINUS-170213403',
#  'SYACIUM-183011000',
#  'SYNODONTIDAE-129040000',
#  'UNKNOWNFISH',
#  'UPENEUSPARVUS-170220605',
#  'UROPHYCISREGIA-148010105',
#  'XANTHICHTHYSRINGENS-189030101'}

# %%
worms_translations = {}
for moniker in new_categories.keys() - full_map.keys():
    search_term = new_categories[moniker].replace("_", " ")
    res = pipeline.resolve(search_term)
    resolved = res['accepted_name'] if res['accepted_name'] else "---"
    print(f"{res['original']:<25} | {res['status']:<10} | {resolved:<25} | {res['notes']}")
    
    worms_translations[new_categories[moniker]] = res
# Out:
# PRONOTOGRAMMUS MARTINICENSIS | RESOLVED   | Pronotogrammus martinicensis |
# LUTJANUS ANALIS           | RESOLVED   | Lutjanus analis           |
# MYCTEROPERCA INTERSTITIALIS | RESOLVED   | Mycteroperca interstitialis |
# SERRANUS ANNULARIS        | RESOLVED   | Serranus annularis        |
# CHROMIS ENCHRYSURUS       | RESOLVED   | Chromis enchrysurus       |
# SCOMBEROMORUS MACULATUS   | RESOLVED   | Scomberomorus maculatus   |
# CARANX RUBER              | RESOLVED   | Caranx ruber              |
# CANTHIGASTER JAMESTYLERI  | RESOLVED   | Canthigaster jamestyleri  |
# SERRANUS ATROBRANCHUS     | RESOLVED   | Serranus atrobranchus     |
# PRISTIGENYS ALTA          | RESOLVED   | Pristigenys alta          |
# SERRANUS PHOEBE           | RESOLVED   | Serranus phoebe           |
# CALAMUS                   | RESOLVED   | Calamus                   |
# LUTJANUS SYNAGRIS         | RESOLVED   | Lutjanus synagris         |
# HOLOCENTRUS               | RESOLVED   | Holocentrus               |
# OSTICHTHYS TRACHYPOMUS    | UNRESOLVED | ---                       | No biological match found.
# EPINEPHELUS ADSCENSIONIS  | RESOLVED   | Epinephelus adscensionis  |
# SYACIUM                   | RESOLVED   | Syacium                   |
# CANTHIDERMIS SUFFLAMEN    | RESOLVED   | Canthidermis sufflamen    |
# CARCHARHINUS FALCIFORMIS  | RESOLVED   | Carcharhinus falciformis  |
# HOLACANTHUS               | RESOLVED   | Holacanthus               |
# LACHNOLAIMUS MAXIMUS      | RESOLVED   | Lachnolaimus maximus      |
# CAULOLATILUS CYANOPS      | RESOLVED   | Caulolatilus cyanops      |
# CARCHARHINUS              | RESOLVED   | Carcharhinus              |
# MYCTEROPERCA              | RESOLVED   | Mycteroperca              |
# HALICHOERES BATHYPHILUS   | RESOLVED   | Halichoeres bathyphilus   |
# MYCTEROPERCA PHENAX       | RESOLVED   | Mycteroperca phenax       |
# CALAMUS LEUCOSTEUS        | RESOLVED   | Calamus leucosteus        |
# XANTHICHTHYS RINGENS      | RESOLVED   | Xanthichthys ringens      |
# LUTJANUS VIVANUS          | RESOLVED   | Lutjanus vivanus          |
# SCOMBEROMORUS             | RESOLVED   | Scomberomorus             |
# CHORDATA                  | RESOLVED   | Chordata                  |
# CHROMIS INSOLATUS         | RESOLVED   | Chromis insolata          |  [Synonym: Chromis insolatus -> Chromis insolata]
# PROGNATHODES AYA          | RESOLVED   | Prognathodes aya          |
# LUTJANUS GRISEUS          | RESOLVED   | Lutjanus griseus          |
# PARANTHIAS FURCIFER       | RESOLVED   | Paranthias furcifer       |
# MYCTEROPERCA BONACI       | RESOLVED   | Mycteroperca bonaci       |
# CENTROPRISTIS PHILADELPHICA | RESOLVED   | Centropristis philadelphica |
# UPENEUS PARVUS            | RESOLVED   | Upeneus parvus            |
# OPHICHTHUS PUNCTICEPS     | RESOLVED   | Ophichthus puncticeps     |
# PTEROIS                   | RESOLVED   | Pterois                   |
# PRIACANTHUS ARENATUS      | RESOLVED   | Priacanthus arenatus      |
# DECAPTERUS                | RESOLVED   | Decapterus                |
# CHAETODIPTERUS FABER      | RESOLVED   | Chaetodipterus faber      |
# SERRANUS SUBLIGARIUS      | RESOLVED   | Serranus subligarius      |
# GOBIIDAE                  | RESOLVED   | Gobiidae                  |
# IOGLOSSUS                 | RESOLVED   | Ptereleotris              |  [Synonym: Ioglossus -> Ptereleotris]
# PAGRUS PAGRUS             | RESOLVED   | Pagrus pagrus             |
# ANTHIINAE                 | RESOLVED   | Anthiadidae               |
# HYPORTHODUS FLAVOLIMBATUS | RESOLVED   | Hyporthodus flavolimbatus |
# HALICHOERES BIVITTATUS    | RESOLVED   | Halichoeres bivittatus    |
# HAEMULON ALBUM            | RESOLVED   | Haemulon album            |
# BALISTES VETULA           | RESOLVED   | Balistes vetula           |
# CANTHIGASTER ROSTRATA     | RESOLVED   | Canthigaster rostrata     |
# CHAETODON                 | RESOLVED   | Chaetodon                 |
# SERIOLA FASCIATA          | RESOLVED   | Seriola fasciata          |
# PAREQUES UMBROSUS         | RESOLVED   | Pareques umbrosus         |
# LUTJANUS                  | RESOLVED   | Lutjanus                  |
# SPHYRNA LEWINI            | RESOLVED   | Sphyrna lewini            |
# BODIANUS PULCHELLUS       | RESOLVED   | Bodianus pulchellus       |
# CEPHALOPHOLIS CRUENTATA   | RESOLVED   | Cephalopholis cruentata   |
# CAULOLATILUS MICROPS      | RESOLVED   | Caulolatilus microps      |
# OPISTOGNATHUS             | RESOLVED   | Opistognathus             |
# CAULOLATILUS CHRYSOPS     | RESOLVED   | Caulolatilus chrysops     |
# CARCHARHINUS PLUMBEUS     | RESOLVED   | Carcharhinus plumbeus     |
# HYPOPLECTRUS              | RESOLVED   | Hypoplectrus              |
# CENTROPRISTIS OCYURUS     | RESOLVED   | Centropristis ocyurus     |
# POMACANTHUS PARU          | RESOLVED   | Pomacanthus paru          |
# CHROMIS                   | RESOLVED   | Chromis                   |
# MULLIDAE                  | RESOLVED   | Mullidae                  |
# SERIOLA DUMERILI          | RESOLVED   | Seriola dumerili          |
# EPINEPHELUS               | RESOLVED   | Epinephelus               |
# DIPLECTRUM FORMOSUM       | RESOLVED   | Diplectrum formosum       |
# CHAETODON CAPISTRATUS     | RESOLVED   | Chaetodon capistratus     |
# CALAMUS NODOSUS           | RESOLVED   | Calamus nodosus           |
# GYMNOTHORAX MORINGA       | RESOLVED   | Gymnothorax moringa       |
# SERRANUS TORTUGARUM       | RESOLVED   | Serranus tortugarum       |
# CALLIONYMIDAE             | RESOLVED   | Callionymidae             |
# SERIOLA                   | RESOLVED   | Seriola                   |
# BODIANUS RUFUS            | RESOLVED   | Bodianus rufus            |
# CHORDATA                  | RESOLVED   | Chordata                  |
# PRISTIPOMOIDES            | RESOLVED   | Pristipomoides            |
# CARANX BARTHOLOMAEI       | RESOLVED   | Caranx bartholomaei       |
# SYNODONTIDAE              | RESOLVED   | Synodontidae              |
# STENOTOMUS CAPRINUS       | RESOLVED   | Stenotomus caprinus       |
# SERIOLA ZONATA            | RESOLVED   | Seriola zonata            |
# ALECTIS CILIARIS          | RESOLVED   | Alectis ciliaris          |
# HOLACANTHUS BERMUDENSIS   | RESOLVED   | Holacanthus bermudensis   |
# CARANGIDAE                | RESOLVED   | Carangidae                |
# BALISTES CAPRISCUS        | RESOLVED   | Balistes capriscus        |
# ANOMURA                   | RESOLVED   | Anomura                   |
# GYMNOTHORAX SAXICOLA      | RESOLVED   | Gymnothorax saxicola      |
# CHAETODON SEDENTARIUS     | RESOLVED   | Chaetodon sedentarius     |
# SPHYRAENA BARRACUDA       | RESOLVED   | Sphyraena barracuda       |
# OPISTOGNATHUS AURIFRONS   | RESOLVED   | Opistognathus aurifrons   |
# ANISOTREMUS VIRGINICUS    | RESOLVED   | Anisotremus virginicus    |
# UROPHYCIS REGIA           | RESOLVED   | Urophycis regia           |
# DERMATOLEPIS INERMIS      | RESOLVED   | Dermatolepis inermis      |
# STENOCIONOPS SPINIMANA    | UNRESOLVED | ---                       | No biological match found.
# CARANX CRYSOS             | RESOLVED   | Caranx crysos             |
# SERIOLA RIVOLIANA         | RESOLVED   | Seriola rivoliana         |
# HAEMULON AUROLINEATUM     | RESOLVED   | Haemulon aurolineatum     |
# GONIOPLECTRUS HISPANUS    | RESOLVED   | Gonioplectrus hispanus    |
# SELENE VOMER              | RESOLVED   | Selene vomer              |
# LUTJANUS APODUS           | RESOLVED   | Lutjanus apodus           |
# CALAMUS PRORIDENS         | RESOLVED   | Calamus proridens         |
# EPINEPHELUS MORIO         | RESOLVED   | Epinephelus morio         |
# MURAENA RETIFERA          | RESOLVED   | Muraena retifera          |
# HALICHOERES               | RESOLVED   | Halichoeres               |
# LUTJANUS CAMPECHANUS      | RESOLVED   | Lutjanus campechanus      |
# SERRANUS                  | RESOLVED   | Serranus                  |
# DECODON PUELLARIS         | RESOLVED   | Decodon puellaris         |
# LIOPROPOMA EUKRINES       | RESOLVED   | Liopropoma eukrines       |
# ALBULA VULPES             | RESOLVED   | Albula vulpes             |
# CALAMUS BAJONADO          | RESOLVED   | Calamus bajonado          |
# RHOMBOPLITES AURORUBENS   | RESOLVED   | Rhomboplites aurorubens   |
# CHAETODON OCELLATUS       | RESOLVED   | Chaetodon ocellatus       |
# POMACANTHUS ARCUATUS      | RESOLVED   | Pomacanthus arcuatus      |
# HOLOCENTRUS ADSCENSIONIS  | RESOLVED   | Holocentrus adscensionis  |
# MONACANTHUS TUCKERI       | RESOLVED   | Monacanthus tuckeri       |
# ARCHOSARGUS PROBATOCEPHALUS | RESOLVED   | Archosargus probatocephalus |
# MALACANTHUS PLUMIERI      | RESOLVED   | Malacanthus plumieri      |
# POMACENTRIDAE             | RESOLVED   | Pomacentridae             |
# MYCTEROPERCA MICROLEPIS   | RESOLVED   | Mycteroperca microlepis   |
# HYPORTHODUS NIGRITUS      | RESOLVED   | Hyporthodus nigritus      |

# %%
for name, res in worms_translations.items():
    if res['status'] != 'RESOLVED':
        print(name)
        print(res)
# Out:
# OSTICHTHYS_TRACHYPOMUS
# {'original': 'OSTICHTHYS TRACHYPOMUS', 'status': 'UNRESOLVED', 'accepted_name': None, 'aphia_id': None, 'candidates': [], 'notes': 'No biological match found.'}
# STENOCIONOPS_SPINIMANA
# {'original': 'STENOCIONOPS SPINIMANA', 'status': 'UNRESOLVED', 'accepted_name': None, 'aphia_id': None, 'candidates': [], 'notes': 'No biological match found.'}

# %%
worms_translations
# Out:
# {'PRONOTOGRAMMUS_MARTINICENSIS': {'original': 'PRONOTOGRAMMUS MARTINICENSIS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Pronotogrammus martinicensis',
#   'aphia_id': 282365,
#   'candidates': [],
#   'notes': ''},
#  'LUTJANUS_ANALIS': {'original': 'LUTJANUS ANALIS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Lutjanus analis',
#   'aphia_id': 159792,
#   'candidates': [],
#   'notes': ''},
#  'MYCTEROPERCA_INTERSTITIALIS': {'original': 'MYCTEROPERCA INTERSTITIALIS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Mycteroperca interstitialis',
#   'aphia_id': 273878,
#   'candidates': [],
#   'notes': ''},
#  'SERRANUS_ANNULARIS': {'original': 'SERRANUS ANNULARIS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Serranus annularis',
#   'aphia_id': 273890,
#   'candidates': [],
#   'notes': ''},
#  'CHROMIS_ENCHRYSURUS': {'original': 'CHROMIS ENCHRYSURUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Chromis enchrysurus',
#   'aphia_id': 304153,
#   'candidates': [],
#   'notes': ''},
#  'SCOMBEROMORUS_MACULATUS': {'original': 'SCOMBEROMORUS MACULATUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Scomberomorus maculatus',
#   'aphia_id': 159342,
#   'candidates': [],
#   'notes': ''},
#  'CARANX_RUBER': {'original': 'CARANX RUBER',
#   'status': 'RESOLVED',
#   'accepted_name': 'Caranx ruber',
#   'aphia_id': 302432,
#   'candidates': [],
#   'notes': ''},
#  'CANTHIGASTER_JAMESTYLERI': {'original': 'CANTHIGASTER JAMESTYLERI',
#   'status': 'RESOLVED',
#   'accepted_name': 'Canthigaster jamestyleri',
#   'aphia_id': 275257,
#   'candidates': [],
#   'notes': ''},
#  'SERRANUS_ATROBRANCHUS': {'original': 'SERRANUS ATROBRANCHUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Serranus atrobranchus',
#   'aphia_id': 273891,
#   'candidates': [],
#   'notes': ''},
#  'PRISTIGENYS_ALTA': {'original': 'PRISTIGENYS ALTA',
#   'status': 'RESOLVED',
#   'accepted_name': 'Pristigenys alta',
#   'aphia_id': 159295,
#   'candidates': [],
#   'notes': ''},
#  'SERRANUS_PHOEBE': {'original': 'SERRANUS PHOEBE',
#   'status': 'RESOLVED',
#   'accepted_name': 'Serranus phoebe',
#   'aphia_id': 273903,
#   'candidates': [],
#   'notes': ''},
#  'CALAMUS': {'original': 'CALAMUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Calamus',
#   'aphia_id': 159240,
#   'candidates': [],
#   'notes': ''},
#  'LUTJANUS_SYNAGRIS': {'original': 'LUTJANUS SYNAGRIS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Lutjanus synagris',
#   'aphia_id': 159800,
#   'candidates': [],
#   'notes': ''},
#  'HOLOCENTRUS': {'original': 'HOLOCENTRUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Holocentrus',
#   'aphia_id': 159376,
#   'candidates': [],
#   'notes': ''},
#  'OSTICHTHYS_TRACHYPOMUS': {'original': 'OSTICHTHYS TRACHYPOMUS',
#   'status': 'UNRESOLVED',
#   'accepted_name': None,
#   'aphia_id': None,
#   'candidates': [],
#   'notes': 'No biological match found.'},
#  'EPINEPHELUS_ADSCENSIONIS': {'original': 'EPINEPHELUS ADSCENSIONIS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Epinephelus adscensionis',
#   'aphia_id': 159351,
#   'candidates': [],
#   'notes': ''},
#  'SYACIUM': {'original': 'SYACIUM',
#   'status': 'RESOLVED',
#   'accepted_name': 'Syacium',
#   'aphia_id': 158875,
#   'candidates': [],
#   'notes': ''},
#  'CANTHIDERMIS_SUFFLAMEN': {'original': 'CANTHIDERMIS SUFFLAMEN',
#   'status': 'RESOLVED',
#   'accepted_name': 'Canthidermis sufflamen',
#   'aphia_id': 127399,
#   'candidates': [],
#   'notes': ''},
#  'CARCHARHINUS_FALCIFORMIS': {'original': 'CARCHARHINUS FALCIFORMIS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Carcharhinus falciformis',
#   'aphia_id': 105789,
#   'candidates': [],
#   'notes': ''},
#  'HOLACANTHUS': {'original': 'HOLACANTHUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Holacanthus',
#   'aphia_id': 159282,
#   'candidates': [],
#   'notes': ''},
#  'LACHNOLAIMUS_MAXIMUS': {'original': 'LACHNOLAIMUS MAXIMUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Lachnolaimus maximus',
#   'aphia_id': 158822,
#   'candidates': [],
#   'notes': ''},
#  'CAULOLATILUS_CYANOPS': {'original': 'CAULOLATILUS CYANOPS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Caulolatilus cyanops',
#   'aphia_id': 159402,
#   'candidates': [],
#   'notes': ''},
#  'CARCHARHINUS': {'original': 'CARCHARHINUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Carcharhinus',
#   'aphia_id': 105719,
#   'candidates': [],
#   'notes': ''},
#  'MYCTEROPERCA': {'original': 'MYCTEROPERCA',
#   'status': 'RESOLVED',
#   'accepted_name': 'Mycteroperca',
#   'aphia_id': 126069,
#   'candidates': [],
#   'notes': ''},
#  'HALICHOERES_BATHYPHILUS': {'original': 'HALICHOERES BATHYPHILUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Halichoeres bathyphilus',
#   'aphia_id': 158814,
#   'candidates': [],
#   'notes': ''},
#  'MYCTEROPERCA_PHENAX': {'original': 'MYCTEROPERCA PHENAX',
#   'status': 'RESOLVED',
#   'accepted_name': 'Mycteroperca phenax',
#   'aphia_id': 159233,
#   'candidates': [],
#   'notes': ''},
#  'CALAMUS_LEUCOSTEUS': {'original': 'CALAMUS LEUCOSTEUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Calamus leucosteus',
#   'aphia_id': 275970,
#   'candidates': [],
#   'notes': ''},
#  'XANTHICHTHYS_RINGENS': {'original': 'XANTHICHTHYS RINGENS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Xanthichthys ringens',
#   'aphia_id': 159486,
#   'candidates': [],
#   'notes': ''},
#  'LUTJANUS_VIVANUS': {'original': 'LUTJANUS VIVANUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Lutjanus vivanus',
#   'aphia_id': 159801,
#   'candidates': [],
#   'notes': ''},
#  'SCOMBEROMORUS': {'original': 'SCOMBEROMORUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Scomberomorus',
#   'aphia_id': 126064,
#   'candidates': [],
#   'notes': ''},
#  'CHORDATA': {'original': 'CHORDATA',
#   'status': 'RESOLVED',
#   'accepted_name': 'Chordata',
#   'aphia_id': 1821,
#   'candidates': [],
#   'notes': ''},
#  'CHROMIS_INSOLATUS': {'original': 'CHROMIS INSOLATUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Chromis insolata',
#   'aphia_id': 273731,
#   'candidates': [],
#   'notes': ' [Synonym: Chromis insolatus -> Chromis insolata]'},
#  'PROGNATHODES_AYA': {'original': 'PROGNATHODES AYA',
#   'status': 'RESOLVED',
#   'accepted_name': 'Prognathodes aya',
#   'aphia_id': 273370,
#   'candidates': [],
#   'notes': ''},
#  'LUTJANUS_GRISEUS': {'original': 'LUTJANUS GRISEUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Lutjanus griseus',
#   'aphia_id': 159797,
#   'candidates': [],
#   'notes': ''},
#  'PARANTHIAS_FURCIFER': {'original': 'PARANTHIAS FURCIFER',
#   'status': 'RESOLVED',
#   'accepted_name': 'Paranthias furcifer',
#   'aphia_id': 282084,
#   'candidates': [],
#   'notes': ''},
#  'MYCTEROPERCA_BONACI': {'original': 'MYCTEROPERCA BONACI',
#   'status': 'RESOLVED',
#   'accepted_name': 'Mycteroperca bonaci',
#   'aphia_id': 159231,
#   'candidates': [],
#   'notes': ''},
#  'CENTROPRISTIS_PHILADELPHICA': {'original': 'CENTROPRISTIS PHILADELPHICA',
#   'status': 'RESOLVED',
#   'accepted_name': 'Centropristis philadelphica',
#   'aphia_id': 159347,
#   'candidates': [],
#   'notes': ''},
#  'UPENEUS_PARVUS': {'original': 'UPENEUS PARVUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Upeneus parvus',
#   'aphia_id': 159422,
#   'candidates': [],
#   'notes': ''},
#  'OPHICHTHUS_PUNCTICEPS': {'original': 'OPHICHTHUS PUNCTICEPS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Ophichthus puncticeps',
#   'aphia_id': 158646,
#   'candidates': [],
#   'notes': ''},
#  'PTEROIS': {'original': 'PTEROIS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Pterois',
#   'aphia_id': 204051,
#   'candidates': [],
#   'notes': ''},
#  'PRIACANTHUS_ARENATUS': {'original': 'PRIACANTHUS ARENATUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Priacanthus arenatus',
#   'aphia_id': 127005,
#   'candidates': [],
#   'notes': ''},
#  'DECAPTERUS': {'original': 'DECAPTERUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Decapterus',
#   'aphia_id': 125937,
#   'candidates': [],
#   'notes': ''},
#  'CHAETODIPTERUS_FABER': {'original': 'CHAETODIPTERUS FABER',
#   'status': 'RESOLVED',
#   'accepted_name': 'Chaetodipterus faber',
#   'aphia_id': 159703,
#   'candidates': [],
#   'notes': ''},
#  'SERRANUS_SUBLIGARIUS': {'original': 'SERRANUS SUBLIGARIUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Serranus subligarius',
#   'aphia_id': 159236,
#   'candidates': [],
#   'notes': ''},
#  'GOBIIDAE': {'original': 'GOBIIDAE',
#   'status': 'RESOLVED',
#   'accepted_name': 'Gobiidae',
#   'aphia_id': 125537,
#   'candidates': [],
#   'notes': ''},
#  'IOGLOSSUS': {'original': 'IOGLOSSUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Ptereleotris',
#   'aphia_id': 204246,
#   'candidates': [],
#   'notes': ' [Synonym: Ioglossus -> Ptereleotris]'},
#  'PAGRUS_PAGRUS': {'original': 'PAGRUS PAGRUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Pagrus pagrus',
#   'aphia_id': 127063,
#   'candidates': [],
#   'notes': ''},
#  'ANTHIINAE': {'original': 'ANTHIINAE',
#   'status': 'RESOLVED',
#   'accepted_name': 'Anthiadidae',
#   'aphia_id': 1758484,
#   'candidates': [],
#   'notes': ''},
#  'HYPORTHODUS_FLAVOLIMBATUS': {'original': 'HYPORTHODUS FLAVOLIMBATUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Hyporthodus flavolimbatus',
#   'aphia_id': 475077,
#   'candidates': [],
#   'notes': ''},
#  'HALICHOERES_BIVITTATUS': {'original': 'HALICHOERES BIVITTATUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Halichoeres bivittatus',
#   'aphia_id': 158815,
#   'candidates': [],
#   'notes': ''},
#  'HAEMULON_ALBUM': {'original': 'HAEMULON ALBUM',
#   'status': 'RESOLVED',
#   'accepted_name': 'Haemulon album',
#   'aphia_id': 275721,
#   'candidates': [],
#   'notes': ''},
#  'BALISTES_VETULA': {'original': 'BALISTES VETULA',
#   'status': 'RESOLVED',
#   'accepted_name': 'Balistes vetula',
#   'aphia_id': 127397,
#   'candidates': [],
#   'notes': ''},
#  'CANTHIGASTER_ROSTRATA': {'original': 'CANTHIGASTER ROSTRATA',
#   'status': 'RESOLVED',
#   'accepted_name': 'Canthigaster rostrata',
#   'aphia_id': 127411,
#   'candidates': [],
#   'notes': ''},
#  'CHAETODON': {'original': 'CHAETODON',
#   'status': 'RESOLVED',
#   'accepted_name': 'Chaetodon',
#   'aphia_id': 125954,
#   'candidates': [],
#   'notes': ''},
#  'SERIOLA_FASCIATA': {'original': 'SERIOLA FASCIATA',
#   'status': 'RESOLVED',
#   'accepted_name': 'Seriola fasciata',
#   'aphia_id': 126817,
#   'candidates': [],
#   'notes': ''},
#  'PAREQUES_UMBROSUS': {'original': 'PAREQUES UMBROSUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Pareques umbrosus',
#   'aphia_id': 282143,
#   'candidates': [],
#   'notes': ''},
#  'LUTJANUS': {'original': 'LUTJANUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Lutjanus',
#   'aphia_id': 159791,
#   'candidates': [],
#   'notes': ''},
#  'SPHYRNA_LEWINI': {'original': 'SPHYRNA LEWINI',
#   'status': 'RESOLVED',
#   'accepted_name': 'Sphyrna lewini',
#   'aphia_id': 105816,
#   'candidates': [],
#   'notes': ''},
#  'BODIANUS_PULCHELLUS': {'original': 'BODIANUS PULCHELLUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Bodianus pulchellus',
#   'aphia_id': 273540,
#   'candidates': [],
#   'notes': ''},
#  'CEPHALOPHOLIS_CRUENTATA': {'original': 'CEPHALOPHOLIS CRUENTATA',
#   'status': 'RESOLVED',
#   'accepted_name': 'Cephalopholis cruentata',
#   'aphia_id': 279146,
#   'candidates': [],
#   'notes': ''},
#  'CAULOLATILUS_MICROPS': {'original': 'CAULOLATILUS MICROPS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Caulolatilus microps',
#   'aphia_id': 159404,
#   'candidates': [],
#   'notes': ''},
#  'OPISTOGNATHUS': {'original': 'OPISTOGNATHUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Opistognathus',
#   'aphia_id': 159746,
#   'candidates': [],
#   'notes': ''},
#  'CAULOLATILUS_CHRYSOPS': {'original': 'CAULOLATILUS CHRYSOPS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Caulolatilus chrysops',
#   'aphia_id': 159403,
#   'candidates': [],
#   'notes': ''},
#  'CARCHARHINUS_PLUMBEUS': {'original': 'CARCHARHINUS PLUMBEUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Carcharhinus plumbeus',
#   'aphia_id': 105797,
#   'candidates': [],
#   'notes': ''},
#  'HYPOPLECTRUS': {'original': 'HYPOPLECTRUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Hypoplectrus',
#   'aphia_id': 269456,
#   'candidates': [],
#   'notes': ''},
#  'CENTROPRISTIS_OCYURUS': {'original': 'CENTROPRISTIS OCYURUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Centropristis ocyurus',
#   'aphia_id': 159346,
#   'candidates': [],
#   'notes': ''},
#  'POMACANTHUS_PARU': {'original': 'POMACANTHUS PARU',
#   'status': 'RESOLVED',
#   'accepted_name': 'Pomacanthus paru',
#   'aphia_id': 276025,
#   'candidates': [],
#   'notes': ''},
#  'CHROMIS': {'original': 'CHROMIS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Chromis',
#   'aphia_id': 126045,
#   'candidates': [],
#   'notes': ''},
#  'MULLIDAE': {'original': 'MULLIDAE',
#   'status': 'RESOLVED',
#   'accepted_name': 'Mullidae',
#   'aphia_id': 125547,
#   'candidates': [],
#   'notes': ''},
#  'SERIOLA_DUMERILI': {'original': 'SERIOLA DUMERILI',
#   'status': 'RESOLVED',
#   'accepted_name': 'Seriola dumerili',
#   'aphia_id': 126816,
#   'candidates': [],
#   'notes': ''},
#  'EPINEPHELUS': {'original': 'EPINEPHELUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Epinephelus',
#   'aphia_id': 126068,
#   'candidates': [],
#   'notes': ''},
#  'DIPLECTRUM_FORMOSUM': {'original': 'DIPLECTRUM FORMOSUM',
#   'status': 'RESOLVED',
#   'accepted_name': 'Diplectrum formosum',
#   'aphia_id': 159350,
#   'candidates': [],
#   'notes': ''},
#  'CHAETODON_CAPISTRATUS': {'original': 'CHAETODON CAPISTRATUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Chaetodon capistratus',
#   'aphia_id': 159661,
#   'candidates': [],
#   'notes': ''},
#  'CALAMUS_NODOSUS': {'original': 'CALAMUS NODOSUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Calamus nodosus',
#   'aphia_id': 159243,
#   'candidates': [],
#   'notes': ''},
#  'GYMNOTHORAX_MORINGA': {'original': 'GYMNOTHORAX MORINGA',
#   'status': 'RESOLVED',
#   'accepted_name': 'Gymnothorax moringa',
#   'aphia_id': 158584,
#   'candidates': [],
#   'notes': ''},
#  'SERRANUS_TORTUGARUM': {'original': 'SERRANUS TORTUGARUM',
#   'status': 'RESOLVED',
#   'accepted_name': 'Serranus tortugarum',
#   'aphia_id': 273910,
#   'candidates': [],
#   'notes': ''},
#  'CALLIONYMIDAE': {'original': 'CALLIONYMIDAE',
#   'status': 'RESOLVED',
#   'accepted_name': 'Callionymidae',
#   'aphia_id': 125522,
#   'candidates': [],
#   'notes': ''},
#  'SERIOLA': {'original': 'SERIOLA',
#   'status': 'RESOLVED',
#   'accepted_name': 'Seriola',
#   'aphia_id': 125944,
#   'candidates': [],
#   'notes': ''},
#  'BODIANUS_RUFUS': {'original': 'BODIANUS RUFUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Bodianus rufus',
#   'aphia_id': 273541,
#   'candidates': [],
#   'notes': ''},
#  'PRISTIPOMOIDES': {'original': 'PRISTIPOMOIDES',
#   'status': 'RESOLVED',
#   'accepted_name': 'Pristipomoides',
#   'aphia_id': 159804,
#   'candidates': [],
#   'notes': ''},
#  'CARANX_BARTHOLOMAEI': {'original': 'CARANX BARTHOLOMAEI',
#   'status': 'RESOLVED',
#   'accepted_name': 'Caranx bartholomaei',
#   'aphia_id': 302312,
#   'candidates': [],
#   'notes': ''},
#  'SYNODONTIDAE': {'original': 'SYNODONTIDAE',
#   'status': 'RESOLVED',
#   'accepted_name': 'Synodontidae',
#   'aphia_id': 125449,
#   'candidates': [],
#   'notes': ''},
#  'STENOTOMUS_CAPRINUS': {'original': 'STENOTOMUS CAPRINUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Stenotomus caprinus',
#   'aphia_id': 159810,
#   'candidates': [],
#   'notes': ''},
#  'SERIOLA_ZONATA': {'original': 'SERIOLA ZONATA',
#   'status': 'RESOLVED',
#   'accepted_name': 'Seriola zonata',
#   'aphia_id': 159650,
#   'candidates': [],
#   'notes': ''},
#  'ALECTIS_CILIARIS': {'original': 'ALECTIS CILIARIS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Alectis ciliaris',
#   'aphia_id': 159629,
#   'candidates': [],
#   'notes': ''},
#  'HOLACANTHUS_BERMUDENSIS': {'original': 'HOLACANTHUS BERMUDENSIS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Holacanthus bermudensis',
#   'aphia_id': 159284,
#   'candidates': [],
#   'notes': ''},
#  'CARANGIDAE': {'original': 'CARANGIDAE',
#   'status': 'RESOLVED',
#   'accepted_name': 'Carangidae',
#   'aphia_id': 125523,
#   'candidates': [],
#   'notes': ''},
#  'BALISTES_CAPRISCUS': {'original': 'BALISTES CAPRISCUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Balistes capriscus',
#   'aphia_id': 154721,
#   'candidates': [],
#   'notes': ''},
#  'ANOMURA': {'original': 'ANOMURA',
#   'status': 'RESOLVED',
#   'accepted_name': 'Anomura',
#   'aphia_id': 106671,
#   'candidates': [],
#   'notes': ''},
#  'GYMNOTHORAX_SAXICOLA': {'original': 'GYMNOTHORAX SAXICOLA',
#   'status': 'RESOLVED',
#   'accepted_name': 'Gymnothorax saxicola',
#   'aphia_id': 158585,
#   'candidates': [],
#   'notes': ''},
#  'CHAETODON_SEDENTARIUS': {'original': 'CHAETODON SEDENTARIUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Chaetodon sedentarius',
#   'aphia_id': 234107,
#   'candidates': [],
#   'notes': ''},
#  'SPHYRAENA_BARRACUDA': {'original': 'SPHYRAENA BARRACUDA',
#   'status': 'RESOLVED',
#   'accepted_name': 'Sphyraena barracuda',
#   'aphia_id': 345843,
#   'candidates': [],
#   'notes': ''},
#  'OPISTOGNATHUS_AURIFRONS': {'original': 'OPISTOGNATHUS AURIFRONS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Opistognathus aurifrons',
#   'aphia_id': 276442,
#   'candidates': [],
#   'notes': ''},
#  'ANISOTREMUS_VIRGINICUS': {'original': 'ANISOTREMUS VIRGINICUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Anisotremus virginicus',
#   'aphia_id': 279625,
#   'candidates': [],
#   'notes': ''},
#  'UROPHYCIS_REGIA': {'original': 'UROPHYCIS REGIA',
#   'status': 'RESOLVED',
#   'accepted_name': 'Urophycis regia',
#   'aphia_id': 158991,
#   'candidates': [],
#   'notes': ''},
#  'DERMATOLEPIS_INERMIS': {'original': 'DERMATOLEPIS INERMIS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Dermatolepis inermis',
#   'aphia_id': 276920,
#   'candidates': [],
#   'notes': ''},
#  'STENOCIONOPS_SPINIMANA': {'original': 'STENOCIONOPS SPINIMANA',
#   'status': 'UNRESOLVED',
#   'accepted_name': None,
#   'aphia_id': None,
#   'candidates': [],
#   'notes': 'No biological match found.'},
#  'CARANX_CRYSOS': {'original': 'CARANX CRYSOS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Caranx crysos',
#   'aphia_id': 126802,
#   'candidates': [],
#   'notes': ''},
#  'SERIOLA_RIVOLIANA': {'original': 'SERIOLA RIVOLIANA',
#   'status': 'RESOLVED',
#   'accepted_name': 'Seriola rivoliana',
#   'aphia_id': 126818,
#   'candidates': [],
#   'notes': ''},
#  'HAEMULON_AUROLINEATUM': {'original': 'HAEMULON AUROLINEATUM',
#   'status': 'RESOLVED',
#   'accepted_name': 'Haemulon aurolineatum',
#   'aphia_id': 158807,
#   'candidates': [],
#   'notes': ''},
#  'GONIOPLECTRUS_HISPANUS': {'original': 'GONIOPLECTRUS HISPANUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Gonioplectrus hispanus',
#   'aphia_id': 280924,
#   'candidates': [],
#   'notes': ''},
#  'SELENE_VOMER': {'original': 'SELENE VOMER',
#   'status': 'RESOLVED',
#   'accepted_name': 'Selene vomer',
#   'aphia_id': 159649,
#   'candidates': [],
#   'notes': ''},
#  'LUTJANUS_APODUS': {'original': 'LUTJANUS APODUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Lutjanus apodus',
#   'aphia_id': 159793,
#   'candidates': [],
#   'notes': ''},
#  'CALAMUS_PRORIDENS': {'original': 'CALAMUS PRORIDENS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Calamus proridens',
#   'aphia_id': 275973,
#   'candidates': [],
#   'notes': ''},
#  'EPINEPHELUS_MORIO': {'original': 'EPINEPHELUS MORIO',
#   'status': 'RESOLVED',
#   'accepted_name': 'Epinephelus morio',
#   'aphia_id': 159354,
#   'candidates': [],
#   'notes': ''},
#  'MURAENA_RETIFERA': {'original': 'MURAENA RETIFERA',
#   'status': 'RESOLVED',
#   'accepted_name': 'Muraena retifera',
#   'aphia_id': 158586,
#   'candidates': [],
#   'notes': ''},
#  'HALICHOERES': {'original': 'HALICHOERES',
#   'status': 'RESOLVED',
#   'accepted_name': 'Halichoeres',
#   'aphia_id': 158813,
#   'candidates': [],
#   'notes': ''},
#  'LUTJANUS_CAMPECHANUS': {'original': 'LUTJANUS CAMPECHANUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Lutjanus campechanus',
#   'aphia_id': 159795,
#   'candidates': [],
#   'notes': ''},
#  'SERRANUS': {'original': 'SERRANUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Serranus',
#   'aphia_id': 126070,
#   'candidates': [],
#   'notes': ''},
#  'DECODON_PUELLARIS': {'original': 'DECODON PUELLARIS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Decodon puellaris',
#   'aphia_id': 276747,
#   'candidates': [],
#   'notes': ''},
#  'LIOPROPOMA_EUKRINES': {'original': 'LIOPROPOMA EUKRINES',
#   'status': 'RESOLVED',
#   'accepted_name': 'Liopropoma eukrines',
#   'aphia_id': 159230,
#   'candidates': [],
#   'notes': ''},
#  'ALBULA_VULPES': {'original': 'ALBULA VULPES',
#   'status': 'RESOLVED',
#   'accepted_name': 'Albula vulpes',
#   'aphia_id': 212256,
#   'candidates': [],
#   'notes': ''},
#  'CALAMUS_BAJONADO': {'original': 'CALAMUS BAJONADO',
#   'status': 'RESOLVED',
#   'accepted_name': 'Calamus bajonado',
#   'aphia_id': 159241,
#   'candidates': [],
#   'notes': ''},
#  'RHOMBOPLITES_AURORUBENS': {'original': 'RHOMBOPLITES AURORUBENS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Rhomboplites aurorubens',
#   'aphia_id': 159807,
#   'candidates': [],
#   'notes': ''},
#  'CHAETODON_OCELLATUS': {'original': 'CHAETODON OCELLATUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Chaetodon ocellatus',
#   'aphia_id': 159662,
#   'candidates': [],
#   'notes': ''},
#  'POMACANTHUS_ARCUATUS': {'original': 'POMACANTHUS ARCUATUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Pomacanthus arcuatus',
#   'aphia_id': 159287,
#   'candidates': [],
#   'notes': ''},
#  'HOLOCENTRUS_ADSCENSIONIS': {'original': 'HOLOCENTRUS ADSCENSIONIS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Holocentrus adscensionis',
#   'aphia_id': 159378,
#   'candidates': [],
#   'notes': ''},
#  'MONACANTHUS_TUCKERI': {'original': 'MONACANTHUS TUCKERI',
#   'status': 'RESOLVED',
#   'accepted_name': 'Monacanthus tuckeri',
#   'aphia_id': 159499,
#   'candidates': [],
#   'notes': ''},
#  'ARCHOSARGUS_PROBATOCEPHALUS': {'original': 'ARCHOSARGUS PROBATOCEPHALUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Archosargus probatocephalus',
#   'aphia_id': 159238,
#   'candidates': [],
#   'notes': ''},
#  'MALACANTHUS_PLUMIERI': {'original': 'MALACANTHUS PLUMIERI',
#   'status': 'RESOLVED',
#   'accepted_name': 'Malacanthus plumieri',
#   'aphia_id': 277261,
#   'candidates': [],
#   'notes': ''},
#  'POMACENTRIDAE': {'original': 'POMACENTRIDAE',
#   'status': 'RESOLVED',
#   'accepted_name': 'Pomacentridae',
#   'aphia_id': 125553,
#   'candidates': [],
#   'notes': ''},
#  'MYCTEROPERCA_MICROLEPIS': {'original': 'MYCTEROPERCA MICROLEPIS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Mycteroperca microlepis',
#   'aphia_id': 273880,
#   'candidates': [],
#   'notes': ''},
#  'HYPORTHODUS_NIGRITUS': {'original': 'HYPORTHODUS NIGRITUS',
#   'status': 'RESOLVED',
#   'accepted_name': 'Hyporthodus nigritus',
#   'aphia_id': 475100,
#   'candidates': [],
#   'notes': ''}}

# %%
manual_lookups = {
    "STENOCIONOPS_SPINIMANA":"Stenocionops spinimanus",
    "OSTICHTHYS_TRACHYPOMUS":"Ostichthys trachypoma"
}

# %%
for full_name, root_name in name_map.items():
    if root_name not in worms_translations:
        continue
    res = worms_translations[root_name]
    print(res)
    if res['status'] == 'RESOLVED':
        full_map[full_name] = res['accepted_name']
    else:
        full_map[full_name] = manual_lookups[root_name]
# Out:
# {'original': 'HYPORTHODUS NIGRITUS', 'status': 'RESOLVED', 'accepted_name': 'Hyporthodus nigritus', 'aphia_id': 475100, 'candidates': [], 'notes': ''}

# %%
full_map
# Out:
# {'ALBULAVULPES-121030101': 'Albula vulpes',
#  'ALECTISCILIARIS-170110101': 'Alectis ciliaris',
#  'ANISOTREMUSVIRGINICUS-170190105': 'Anisotremus virginicus',
#  'ARCHOSARGUSPROBATOCEPHALUS-170213601': 'Archosargus probatocephalus',
#  'BALISTESCAPRISCUS-189030502': 'Balistes capriscus',
#  'BALISTESVETULA-189030504': 'Balistes vetula',
#  'BODIANUSPULCHELLUS-170280201': 'Bodianus pulchellus',
#  'BODIANUSRUFUS-170280202': 'Bodianus rufus',
#  'CALAMUSBAJONADO-170210602': 'Calamus bajonado',
#  'CALAMUSLEUCOSTEUS-170210604': 'Calamus leucosteus',
#  'CALAMUSNODOSUS-170210608': 'Calamus nodosus',
#  'CALAMUSPRORIDENS-170210605': 'Calamus proridens',
#  'CALLIONYMIDAE-170420000': 'Callionymidae',
#  'CANTHIDERMISSUFFLAMEN-189030402': 'Canthidermis sufflamen',
#  'CANTHIGASTERJAMESTYLERI-189080102': 'Canthigaster jamestyleri',
#  'CARANXBARTHOLOMAEI-170110801': 'Caranx bartholomaei',
#  'CARANXCRYSOS-170110803': 'Caranx crysos',
#  'CARANXRUBER-170110807': 'Caranx ruber',
#  'CAULOLATILUSCHRYSOPS-170070104': 'Caulolatilus chrysops',
#  'CAULOLATILUSCYANOPS-170070101': 'Caulolatilus cyanops',
#  'CAULOLATILUSMICROPS-170070103': 'Caulolatilus microps',
#  'CENTROPRISTISPHILADELPHICA-170024805': 'Centropristis philadelphica',
#  'CEPHALOPHOLISCRUENTATA-170020401': 'Cephalopholis cruentata',
#  'CHAETODIPTERUSFABER-170250101': 'Chaetodipterus faber',
#  'CHAETODONCAPISTRATUS-170260302': 'Chaetodon capistratus',
#  'CHAETODONOCELLATUS-170260307': 'Chaetodon ocellatus',
#  'CHAETODONSEDENTARIUS-170260309': 'Chaetodon sedentarius',
#  'CHROMISENCHRYSURUS-170270302': 'Chromis enchrysurus',
#  'CHROMISINSOLATUS-170270304': 'Chromis insolata',
#  'DECODONPUELLARIS-170283001': 'Decodon puellaris',
#  'DERMATOLEPISINERMIS-170020301': 'Dermatolepis inermis',
#  'DIPLECTRUMFORMOSUM-170020903': 'Diplectrum formosum',
#  'EPINEPHELUSADSCENSIONIS-170021203': 'Epinephelus adscensionis',
#  'EPINEPHELUSMORIO-170021211': 'Epinephelus morio',
#  'GONIOPLECTRUSHISPANUS-170021403': 'Gonioplectrus hispanus',
#  'GYMNOTHORAXMORINGA-143060202': 'Gymnothorax moringa',
#  'GYMNOTHORAXSAXICOLA-143060205': 'Gymnothorax saxicola',
#  'HAEMULONALBUM-170191002': 'Haemulon album',
#  'HAEMULONAUROLINEATUM-170191003': 'Haemulon aurolineatum',
#  'HALICHOERESBATHYPHILUS-170281201': 'Halichoeres bathyphilus',
#  'HALICHOERESBIVITTATUS-170281202': 'Halichoeres bivittatus',
#  'HOLACANTHUSBERMUDENSIS-170290102': 'Holacanthus bermudensis',
#  'HOLOCENTRUSADSCENSIONIS-161110201': 'Holocentrus adscensionis',
#  'LACHNOLAIMUSMAXIMUS-170281801': 'Lachnolaimus maximus',
#  'LIOPROPOMAEUKRINES-170025602': 'Liopropoma eukrines',
#  'LUTJANUSANALIS-170151101': 'Lutjanus analis',
#  'LUTJANUSAPODUS-170151102': 'Lutjanus apodus',
#  'LUTJANUSCAMPECHANUS-170151107': 'Lutjanus campechanus',
#  'LUTJANUSGRISEUS-170151109': 'Lutjanus griseus',
#  'LUTJANUSSYNAGRIS-170151113': 'Lutjanus synagris',
#  'LUTJANUSVIVANUS-170151114': 'Lutjanus vivanus',
#  'MALACANTHUSPLUMIERI-170070301': 'Malacanthus plumieri',
#  'MURAENARETIFERA-143060402': 'Muraena retifera',
#  'MYCTEROPERCABONACI-170022101': 'Mycteroperca bonaci',
#  'MYCTEROPERCAINTERSTITIALIS-170022103': 'Mycteroperca interstitialis',
#  'MYCTEROPERCAMICROLEPIS-170022104': 'Mycteroperca microlepis',
#  'MYCTEROPERCAPHENAX-170022105': 'Mycteroperca phenax',
#  'OPHICHTHUSPUNCTICEPS-143150402': 'Ophichthus puncticeps',
#  'OSTICHTHYSTRACHYPOMUS-161110601': 'Ostichthys trachypoma',
#  'PAGRUSPAGRUS-170212302': 'Pagrus pagrus',
#  'PARANTHIASFURCIFER-170022701': 'Paranthias furcifer',
#  'POMACANTHUSARCUATUS-170290201': 'Pomacanthus arcuatus',
#  'POMACANTHUSPARU-170290203': 'Pomacanthus paru',
#  'PRIACANTHUSARENATUS-170050101': 'Priacanthus arenatus',
#  'PRISTIGENYSALTA-170050401': 'Pristigenys alta',
#  'PTEROIS-168011900': 'Pterois',
#  'RHOMBOPLITESAURORUBENS-170152001': 'Rhomboplites aurorubens',
#  'SCOMBEROMORUSMACULATUS-170440803': 'Scomberomorus maculatus',
#  'SELENEVOMER-170113003': 'Selene vomer',
#  'SERIOLADUMERILI-170113101': 'Seriola dumerili',
#  'SERIOLAFASCIATA-170113103': 'Seriola fasciata',
#  'SERIOLARIVOLIANA-170113105': 'Seriola rivoliana',
#  'SERIOLAZONATA-170113106': 'Seriola zonata',
#  'SERRANUSANNULARIS-170024201': 'Serranus annularis',
#  'SERRANUSATROBRANCHUS-170024202': 'Serranus atrobranchus',
#  'SERRANUSSUBLIGARIUS-170024209': 'Serranus subligarius',
#  'SERRANUSPHOEBE-170024208': 'Serranus phoebe',
#  'SPHYRAENABARRACUDA-165030101': 'Sphyraena barracuda',
#  'STENOCIONOPSSPINIMANA-229211803': 'Stenocionops spinimanus',
#  'UPENEUSPARVUS-170220605': 'Upeneus parvus',
#  'UROPHYCISREGIA-148010105': 'Urophycis regia',
#  'XANTHICHTHYSRINGENS-189030101': 'Xanthichthys ringens',
#  'ANOMURA-999100401': 'Anomura',
#  'ANTHIINAE-999020300': 'Anthiadidae',
#  'CALAMUS-170210600': 'Calamus',
#  'CANTHIGASTERROSTRATA-189080101': 'Canthigaster rostrata',
#  'CARANGIDAE-170110000': 'Carangidae',
#  'CARCHARHINUSFALCIFORMIS-108020202': 'Carcharhinus falciformis',
#  'CARCHARHINUSPLUMBEUS-108020208': 'Carcharhinus plumbeus',
#  'CARCHARHINUS-108020200': 'Carcharhinus',
#  'CENTROPRISTISOCYURUS-170024804': 'Centropristis ocyurus',
#  'CHAETODON-170260300': 'Chaetodon',
#  'CHROMIS-170270300': 'Chromis',
#  'DECAPTERUS-170111200': 'Decapterus',
#  'EPINEPHELUS-170021200': 'Epinephelus',
#  'GOBIIDAE-170550000': 'Gobiidae',
#  'HALICHOERES-170281200': 'Halichoeres',
#  'HOLACANTHUS-170290100': 'Holacanthus',
#  'HOLOCENTRUS-161110200': 'Holocentrus',
#  'HYPOPLECTRUS-170021500': 'Hypoplectrus',
#  'HYPORTHODUSFLAVOLIMBATUS-170021206': 'Hyporthodus flavolimbatus',
#  'IOGLOSSUS-170550800': 'Ptereleotris',
#  'LUTJANUS-170151100': 'Lutjanus',
#  'MONACANTHUSTUCKERI-189040203': 'Monacanthus tuckeri',
#  'MULLIDAE-170220000': 'Mullidae',
#  'MYCTEROPERCA-170022100': 'Mycteroperca',
#  'OPISTOGNATHUSAURIFRONS-170310203': 'Opistognathus aurifrons',
#  'OPISTOGNATHUS-170310200': 'Opistognathus',
#  'PAREQUESUMBROSUS-170201105': 'Pareques umbrosus',
#  'POMACENTRIDAE-170270000': 'Pomacentridae',
#  'PRISTIPOMOIDES-170151800': 'Pristipomoides',
#  'PROGNATHODESAYA-170260301': 'Prognathodes aya',
#  'PRONOTOGRAMMUSMARTINICENSIS-170025101': 'Pronotogrammus martinicensis',
#  'SCOMBEROMORUS-170440800': 'Scomberomorus',
#  'SERIOLA-170113100': 'Seriola',
#  'SERRANUSTORTUGARUM-170024211': 'Serranus tortugarum',
#  'SERRANUS-170024200': 'Serranus',
#  'SPHYRNALEWINI-108040102': 'Sphyrna lewini',
#  'STENOTOMUSCAPRINUS-170213403': 'Stenotomus caprinus',
#  'SYACIUM-183011000': 'Syacium',
#  'SYNODONTIDAE-129040000': 'Synodontidae',
#  'UNKNOWNFISH': 'Chordata',
#  'SCHOOL': 'Chordata',
#  'HYPORTHODUSNIGRITUS-170021202': 'Hyporthodus nigritus'}

# %%
with open('worms_map.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(["GFISHER name", "WORMS name"])
    writer.writerows(full_map.items())
