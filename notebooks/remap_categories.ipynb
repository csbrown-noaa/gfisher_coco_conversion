# %%
import pycocowriter.cocomerge
import csv
import json
import tempfile
from pynoddgcs.connect import GCS

# %%
SOURCE_BUCKET = "nmfs_odp_hq"
SOURCE_FILE = "nodd_tools/datasets/gfisher/annotations.json"
DESTINATION_FILE = "nodd_tools/datasets/gfisher/annotations_worms.json"

# %%
client = GCS()

# %%
with open('worms_map.csv', 'r') as f:
    reader = csv.reader(f)
    header = next(reader)
    name_map = {row[0]: row[1] for row in reader}

# %%
with tempfile.NamedTemporaryFile() as f:
    client.download(SOURCE_BUCKET, SOURCE_FILE, f.name)
    raw_coco = json.load(f)

# %% [raw]
# len(json.dumps(raw_coco))

# %%
108965130
# Out:
# 108965130

# %% [markdown]
# ## Updating "crowd" type categories to have the "iscrowd" attribute
#
# "SCHOOL" and possibly others are "crowd" type categories.

# %%
crowd_categories = set(["SCHOOL"])
crowd_category_ids = set([cat["id"] for cat in raw_coco["categories"] if cat["name"] in crowd_categories])
for ann in raw_coco["annotations"]:
    if ann["id"] in crowd_category_ids:
        ann["iscrowd"] = 1
crowd_category_ids
# Out:
# {114}

# %%
pycocowriter.cocomerge.coco_remap_categories(raw_coco, name_map)
pycocowriter.cocomerge.coco_collapse_categories(raw_coco)
pycocowriter.cocomerge.coco_reindex_categories(raw_coco)
raw_coco['categories']
# Out:
# [{'name': 'Mycteroperca microlepis', 'id': 1},
#  {'name': 'Serranus phoebe', 'id': 2},
#  {'name': 'Seriola fasciata', 'id': 3},
#  {'name': 'Rhomboplites aurorubens', 'id': 4},
#  {'name': 'Lutjanus synagris', 'id': 5},
#  {'name': 'Callionymidae', 'id': 6},
#  {'name': 'Epinephelus morio', 'id': 7},
#  {'name': 'Halichoeres', 'id': 8},
#  {'name': 'Pterois', 'id': 9},
#  {'name': 'Bodianus pulchellus', 'id': 10},
#  {'name': 'Haemulon aurolineatum', 'id': 11},
#  {'name': 'Lutjanus griseus', 'id': 12},
#  {'name': 'Pomacentridae', 'id': 13},
#  {'name': 'Seriola', 'id': 14},
#  {'name': 'Pristigenys alta', 'id': 15},
#  {'name': 'Caranx bartholomaei', 'id': 16},
#  {'name': 'Balistes capriscus', 'id': 17},
#  {'name': 'Lutjanus campechanus', 'id': 18},
#  {'name': 'Chaetodon ocellatus', 'id': 19},
#  {'name': 'Holacanthus bermudensis', 'id': 20},
#  {'name': 'Mycteroperca phenax', 'id': 21},
#  {'name': 'Cephalopholis cruentata', 'id': 22},
#  {'name': 'Lutjanus', 'id': 23},
#  {'name': 'Scomberomorus maculatus', 'id': 24},
#  {'name': 'Caranx crysos', 'id': 25},
#  {'name': 'Chaetodon sedentarius', 'id': 26},
#  {'name': 'Pagrus pagrus', 'id': 27},
#  {'name': 'Diplectrum formosum', 'id': 28},
#  {'name': 'Chaetodon', 'id': 29},
#  {'name': 'Calamus', 'id': 30},
#  {'name': 'Seriola rivoliana', 'id': 31},
#  {'name': 'Lutjanus vivanus', 'id': 32},
#  {'name': 'Balistes vetula', 'id': 33},
#  {'name': 'Mycteroperca interstitialis', 'id': 34},
#  {'name': 'Serranus annularis', 'id': 35},
#  {'name': 'Mycteroperca bonaci', 'id': 36},
#  {'name': 'Canthigaster rostrata', 'id': 37},
#  {'name': 'Halichoeres bivittatus', 'id': 38},
#  {'name': 'Paranthias furcifer', 'id': 39},
#  {'name': 'Pronotogrammus martinicensis', 'id': 40},
#  {'name': 'Opistognathus', 'id': 41},
#  {'name': 'Serranus', 'id': 42},
#  {'name': 'Seriola zonata', 'id': 43},
#  {'name': 'Sphyrna lewini', 'id': 44},
#  {'name': 'Mycteroperca', 'id': 45},
#  {'name': 'Anisotremus virginicus', 'id': 46},
#  {'name': 'Hyporthodus nigritus', 'id': 47},
#  {'name': 'Carangidae', 'id': 48},
#  {'name': 'Chromis', 'id': 49},
#  {'name': 'Chaetodon capistratus', 'id': 50},
#  {'name': 'Priacanthus arenatus', 'id': 51},
#  {'name': 'Xanthichthys ringens', 'id': 52},
#  {'name': 'Holocentrus', 'id': 53},
#  {'name': 'Calamus leucosteus', 'id': 54},
#  {'name': 'Anomura', 'id': 55},
#  {'name': 'Seriola dumerili', 'id': 56},
#  {'name': 'Lachnolaimus maximus', 'id': 57},
#  {'name': 'Upeneus parvus', 'id': 58},
#  {'name': 'Ptereleotris', 'id': 59},
#  {'name': 'Malacanthus plumieri', 'id': 60},
#  {'name': 'Halichoeres bathyphilus', 'id': 61},
#  {'name': 'Carcharhinus', 'id': 62},
#  {'name': 'Decapterus', 'id': 63},
#  {'name': 'Carcharhinus plumbeus', 'id': 64},
#  {'name': 'Synodontidae', 'id': 65},
#  {'name': 'Syacium', 'id': 66},
#  {'name': 'Canthidermis sufflamen', 'id': 67},
#  {'name': 'Alectis ciliaris', 'id': 68},
#  {'name': 'Gobiidae', 'id': 69},
#  {'name': 'Epinephelus', 'id': 70},
#  {'name': 'Urophycis regia', 'id': 71},
#  {'name': 'Opistognathus aurifrons', 'id': 72},
#  {'name': 'Centropristis ocyurus', 'id': 73},
#  {'name': 'Muraena retifera', 'id': 74},
#  {'name': 'Dermatolepis inermis', 'id': 75},
#  {'name': 'Pomacanthus arcuatus', 'id': 76},
#  {'name': 'Pareques umbrosus', 'id': 77},
#  {'name': 'Ophichthus puncticeps', 'id': 78},
#  {'name': 'Pomacanthus paru', 'id': 79},
#  {'name': 'Hyporthodus flavolimbatus', 'id': 80},
#  {'name': 'Chromis enchrysurus', 'id': 81},
#  {'name': 'Lutjanus apodus', 'id': 82},
#  {'name': 'Calamus nodosus', 'id': 83},
#  {'name': 'Carcharhinus falciformis', 'id': 84},
#  {'name': 'Anthiadidae', 'id': 85},
#  {'name': 'Gymnothorax saxicola', 'id': 86},
#  {'name': 'Caulolatilus cyanops', 'id': 87},
#  {'name': 'Gymnothorax moringa', 'id': 88},
#  {'name': 'Calamus proridens', 'id': 89},
#  {'name': 'Holocentrus adscensionis', 'id': 90},
#  {'name': 'Sphyraena barracuda', 'id': 91},
#  {'name': 'Hypoplectrus', 'id': 92},
#  {'name': 'Calamus bajonado', 'id': 93},
#  {'name': 'Caranx ruber', 'id': 94},
#  {'name': 'Gonioplectrus hispanus', 'id': 95},
#  {'name': 'Bodianus rufus', 'id': 96},
#  {'name': 'Epinephelus adscensionis', 'id': 97},
#  {'name': 'Prognathodes aya', 'id': 98},
#  {'name': 'Decodon puellaris', 'id': 99},
#  {'name': 'Caulolatilus microps', 'id': 100},
#  {'name': 'Stenocionops spinimanus', 'id': 101},
#  {'name': 'Caulolatilus chrysops', 'id': 102},
#  {'name': 'Ostichthys trachypoma', 'id': 103},
#  {'name': 'Lutjanus analis', 'id': 104},
#  {'name': 'Chromis insolata', 'id': 105},
#  {'name': 'Serranus tortugarum', 'id': 106},
#  {'name': 'Monacanthus tuckeri', 'id': 107},
#  {'name': 'Canthigaster jamestyleri', 'id': 108},
#  {'name': 'Liopropoma eukrines', 'id': 109},
#  {'name': 'Mullidae', 'id': 110},
#  {'name': 'Haemulon album', 'id': 111},
#  {'name': 'Pristipomoides', 'id': 112},
#  {'name': 'Chordata', 'id': 113},
#  {'name': 'Serranus atrobranchus', 'id': 114},
#  {'name': 'Albula vulpes', 'id': 115},
#  {'name': 'Archosargus probatocephalus', 'id': 116},
#  {'name': 'Scomberomorus', 'id': 117},
#  {'name': 'Centropristis philadelphica', 'id': 118},
#  {'name': 'Stenotomus caprinus', 'id': 119},
#  {'name': 'Selene vomer', 'id': 120},
#  {'name': 'Chaetodipterus faber', 'id': 121},
#  {'name': 'Holacanthus', 'id': 122},
#  {'name': 'Serranus subligarius', 'id': 123}]

# %% [raw]
# len(json.dumps(raw_coco))

# %% [markdown]
# ## Upload the rectified file to GCS

# %%
with tempfile.NamedTemporaryFile('w') as f:
    json.dump(raw_coco, f)
    f.flush()
    client.upload(SOURCE_BUCKET, f.name, DESTINATION_FILE)
# Out:
# File /tmp/tmp7ong7bb1 uploaded to nodd_tools/datasets/gfisher/annotations_worms.json.
